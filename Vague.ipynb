# %%
import tensorflow as tf
#import keras
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns

import nltk
from nltk.corpus import nps_chat
import pandas as pd 
import re
import pickle
import io
import datetime

import os
from os import makedirs
from os import chdir
from os import path
cwd = os.getcwd()
# Out:
# Using TensorFlow backend.

# %%
prop_data = pd.read_csv(cwd + '/vagueCorpora/prop.csv')
speechact_data = pd.read_csv(cwd + '/vagueCorpora/speech.csv')

# %%
prop_data
# Out:
#       id                                        text  vague  type
# 0      1                 yeah there is around twenty      1  prop
# 1      2  i think it was something like two or three      1  prop
# 2      3                           about one hundred      1  prop
# 3      4                           approximately six      1  prop
# 4      5                           thirty four or so      1  prop
# ..   ...                                         ...    ...   ...
# 395  396                   i have a wireless speaker      0  prop
# 396  397                  this lighter is from spain      0  prop
# 397  398                          my console is load      0  prop
# 398  399                   zoom is better than skype      0  prop
# 399  400                          it can play movies      0  prop
#
# [400 rows x 4 columns]

# %%
def split_data(text, labels, split_size):
    sentences_train, sentences_test, label_train, label_test = train_test_split(text, labels, test_size = split_size, random_state = 42)
    
    sentences_train = np.array(sentences_train)
    label_train = np.array(label_train)
    sentences_test = np.array(sentences_test)
    label_test = np.array(label_test)
    
    return sentences_train, sentences_test, label_train, label_test

# %%
max_length = 200

def make_sequences(tok, train_text, test_text):
    training_sequences = tok.texts_to_sequences(train_text)
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding = 'post', truncating = 'post')
    
    testing_sequences = tok.texts_to_sequences(test_text)
    testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding = 'post', truncating = 'post')
    
    return training_padded, testing_padded

# %%
def clean_text(text):
    text = text.lower()
    
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"\?", "", text)
    text = re.sub(r"\!", "", text)
    text = re.sub(r"\.", "", text)
    text = re.sub(r"\,", "", text)
    text = re.sub(r"\r\n", "", text)
    return text

# %%
speechact_data['id'] = speechact_data['id'].apply(lambda x: x + 400)

VL_dataset = prop_data.append(speechact_data).set_index('id')

type_labels = VL_dataset['type'].tolist()
sentencesRaw = VL_dataset['text'].tolist()
sentences = list(map(clean_text, sentencesRaw))

type_test_size = 0.8
type_train, type_test, type_label_train, type_label_test = split_data(sentences, type_labels, type_test_size)
# Out:
# /home/jason/.local/lib/python3.6/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
nl_type_train, nl_type_test = [],[]

def number_label(l, new_l):
    for element in l:
        if(element == 'prop'):
            new_l.append(0)
        elif(element == 'speech act'):
            new_l.append(1)
            
number_label(type_label_train, nl_type_train)
number_label(type_label_test, nl_type_test)

nl_type_train, nl_type_test = np.array(nl_type_train), np.array(nl_type_test)

# %%
type_tok = Tokenizer(oov_token="<OOV>")
type_tok.fit_on_texts(type_train)
type_word_index = type_tok.word_index
type_vocab_size = len(type_word_index) + 1

# %%
type_train_padded, type_test_padded = make_sequences(type_tok, type_train, type_test)

# %%
type_train_padded.shape
# Out:
# (100, 200)

# %%
type_embedding_dim = 128

type_model = tf.keras.Sequential([
        tf.keras.layers.Embedding(type_vocab_size, type_embedding_dim, 
                                  input_length = max_length, name = 'TYPEembed'),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(512, activation = 'sigmoid'),
        tf.keras.layers.Dense(2, activation = 'sigmoid'),
    ])

type_model.compile(loss = 'sparse_categorical_crossentropy', 
                   optimizer = 'adam', metrics = ['accuracy'])

type_model.summary()

type_history = type_model.fit(type_train_padded, nl_type_train, epochs = 300, 
                              validation_data = (type_test_padded, nl_type_test), 
                              verbose = 2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# TYPEembed (Embedding)        (None, 200, 128)          39552
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 106,626
# Trainable params: 106,626
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 4/4 - 0s - loss: 0.5956 - accuracy: 0.7900 - val_loss: 0.5043 - val_accuracy: 0.8025
# Epoch 2/300
# 4/4 - 0s - loss: 0.5167 - accuracy: 0.7900 - val_loss: 0.4992 - val_accuracy: 0.8025
# Epoch 3/300
# 4/4 - 0s - loss: 0.5153 - accuracy: 0.7900 - val_loss: 0.4993 - val_accuracy: 0.8025
# Epoch 4/300
# 4/4 - 0s - loss: 0.5189 - accuracy: 0.7900 - val_loss: 0.4970 - val_accuracy: 0.8025
# Epoch 5/300
# 4/4 - 0s - loss: 0.5152 - accuracy: 0.7900 - val_loss: 0.4972 - val_accuracy: 0.8025
# Epoch 6/300
# 4/4 - 0s - loss: 0.5160 - accuracy: 0.7900 - val_loss: 0.4974 - val_accuracy: 0.8025
# Epoch 7/300
# 4/4 - 0s - loss: 0.5146 - accuracy: 0.7900 - val_loss: 0.4978 - val_accuracy: 0.8025
# Epoch 8/300
# 4/4 - 0s - loss: 0.5129 - accuracy: 0.7900 - val_loss: 0.5032 - val_accuracy: 0.8025
# Epoch 9/300
# 4/4 - 0s - loss: 0.5231 - accuracy: 0.7900 - val_loss: 0.5171 - val_accuracy: 0.8025
# Epoch 10/300
# 4/4 - 0s - loss: 0.5288 - accuracy: 0.7900 - val_loss: 0.5101 - val_accuracy: 0.8025
# Epoch 11/300
# 4/4 - 0s - loss: 0.5226 - accuracy: 0.7900 - val_loss: 0.4977 - val_accuracy: 0.8025
# Epoch 12/300
# 4/4 - 0s - loss: 0.5132 - accuracy: 0.7900 - val_loss: 0.4978 - val_accuracy: 0.8025
# Epoch 13/300
# 4/4 - 0s - loss: 0.5168 - accuracy: 0.7900 - val_loss: 0.4972 - val_accuracy: 0.8025
# Epoch 14/300
# 4/4 - 0s - loss: 0.5154 - accuracy: 0.7900 - val_loss: 0.4969 - val_accuracy: 0.8025
# Epoch 15/300
# 4/4 - 0s - loss: 0.5155 - accuracy: 0.7900 - val_loss: 0.4987 - val_accuracy: 0.8025
# Epoch 16/300
# 4/4 - 0s - loss: 0.5141 - accuracy: 0.7900 - val_loss: 0.5036 - val_accuracy: 0.8025
# Epoch 17/300
# 4/4 - 0s - loss: 0.5204 - accuracy: 0.7900 - val_loss: 0.5054 - val_accuracy: 0.8025
# Epoch 18/300
# 4/4 - 0s - loss: 0.5189 - accuracy: 0.7900 - val_loss: 0.4991 - val_accuracy: 0.8025
# Epoch 19/300
# 4/4 - 0s - loss: 0.5147 - accuracy: 0.7900 - val_loss: 0.4970 - val_accuracy: 0.8025
# Epoch 20/300
# 4/4 - 0s - loss: 0.5135 - accuracy: 0.7900 - val_loss: 0.4967 - val_accuracy: 0.8025
# Epoch 21/300
# 4/4 - 0s - loss: 0.5136 - accuracy: 0.7900 - val_loss: 0.4972 - val_accuracy: 0.8025
# Epoch 22/300
# 4/4 - 0s - loss: 0.5160 - accuracy: 0.7900 - val_loss: 0.4967 - val_accuracy: 0.8025
# Epoch 23/300
# 4/4 - 0s - loss: 0.5157 - accuracy: 0.7900 - val_loss: 0.4980 - val_accuracy: 0.8025
# Epoch 24/300
# 4/4 - 0s - loss: 0.5145 - accuracy: 0.7900 - val_loss: 0.4995 - val_accuracy: 0.8025
# Epoch 25/300
# 4/4 - 0s - loss: 0.5137 - accuracy: 0.7900 - val_loss: 0.5021 - val_accuracy: 0.8025
# Epoch 26/300
# 4/4 - 0s - loss: 0.5170 - accuracy: 0.7900 - val_loss: 0.5031 - val_accuracy: 0.8025
# Epoch 27/300
# 4/4 - 0s - loss: 0.5165 - accuracy: 0.7900 - val_loss: 0.5034 - val_accuracy: 0.8025
# Epoch 28/300
# 4/4 - 0s - loss: 0.5196 - accuracy: 0.7900 - val_loss: 0.5082 - val_accuracy: 0.8025
# Epoch 29/300
# 4/4 - 0s - loss: 0.5191 - accuracy: 0.7900 - val_loss: 0.5000 - val_accuracy: 0.8025
# Epoch 30/300
# 4/4 - 0s - loss: 0.5134 - accuracy: 0.7900 - val_loss: 0.4959 - val_accuracy: 0.8025
# Epoch 31/300
# 4/4 - 0s - loss: 0.5109 - accuracy: 0.7900 - val_loss: 0.4993 - val_accuracy: 0.8025
# Epoch 32/300
# 4/4 - 0s - loss: 0.5193 - accuracy: 0.7900 - val_loss: 0.4998 - val_accuracy: 0.8025
# Epoch 33/300
# 4/4 - 0s - loss: 0.5173 - accuracy: 0.7900 - val_loss: 0.4969 - val_accuracy: 0.8025
# Epoch 34/300
# 4/4 - 0s - loss: 0.5135 - accuracy: 0.7900 - val_loss: 0.4951 - val_accuracy: 0.8025
# Epoch 35/300
# 4/4 - 0s - loss: 0.5098 - accuracy: 0.7900 - val_loss: 0.4982 - val_accuracy: 0.8025
# Epoch 36/300
# 4/4 - 0s - loss: 0.5123 - accuracy: 0.7900 - val_loss: 0.5018 - val_accuracy: 0.8025
# Epoch 37/300
# 4/4 - 0s - loss: 0.5123 - accuracy: 0.7900 - val_loss: 0.4968 - val_accuracy: 0.8025
# Epoch 38/300
# 4/4 - 0s - loss: 0.5068 - accuracy: 0.7900 - val_loss: 0.4940 - val_accuracy: 0.8025
# Epoch 39/300
# 4/4 - 0s - loss: 0.5098 - accuracy: 0.7900 - val_loss: 0.4951 - val_accuracy: 0.8025
# Epoch 40/300
# 4/4 - 0s - loss: 0.5102 - accuracy: 0.7900 - val_loss: 0.4961 - val_accuracy: 0.8025
# Epoch 41/300
# 4/4 - 0s - loss: 0.5113 - accuracy: 0.7900 - val_loss: 0.4944 - val_accuracy: 0.8025
# Epoch 42/300
# 4/4 - 0s - loss: 0.5089 - accuracy: 0.7900 - val_loss: 0.4931 - val_accuracy: 0.8025
# Epoch 43/300
# 4/4 - 0s - loss: 0.5012 - accuracy: 0.7900 - val_loss: 0.4941 - val_accuracy: 0.8025
# Epoch 44/300
# 4/4 - 0s - loss: 0.5021 - accuracy: 0.7900 - val_loss: 0.5076 - val_accuracy: 0.8025
# Epoch 45/300
# 4/4 - 0s - loss: 0.5187 - accuracy: 0.7900 - val_loss: 0.5186 - val_accuracy: 0.8025
# Epoch 46/300
# 4/4 - 0s - loss: 0.5202 - accuracy: 0.7900 - val_loss: 0.5056 - val_accuracy: 0.8025
# Epoch 47/300
# 4/4 - 0s - loss: 0.5066 - accuracy: 0.7900 - val_loss: 0.4936 - val_accuracy: 0.8025
# Epoch 48/300
# 4/4 - 0s - loss: 0.5005 - accuracy: 0.7900 - val_loss: 0.4895 - val_accuracy: 0.8025
# Epoch 49/300
# 4/4 - 0s - loss: 0.4977 - accuracy: 0.7900 - val_loss: 0.4889 - val_accuracy: 0.8025
# Epoch 50/300
# 4/4 - 0s - loss: 0.4962 - accuracy: 0.7900 - val_loss: 0.4883 - val_accuracy: 0.8025
# Epoch 51/300
# 4/4 - 0s - loss: 0.4953 - accuracy: 0.7900 - val_loss: 0.4878 - val_accuracy: 0.8025
# Epoch 52/300
# 4/4 - 0s - loss: 0.4957 - accuracy: 0.7900 - val_loss: 0.4877 - val_accuracy: 0.8025
# Epoch 53/300
# 4/4 - 0s - loss: 0.4931 - accuracy: 0.7900 - val_loss: 0.4858 - val_accuracy: 0.8025
# Epoch 54/300
# 4/4 - 0s - loss: 0.4899 - accuracy: 0.7900 - val_loss: 0.4854 - val_accuracy: 0.8025
# Epoch 55/300
# 4/4 - 0s - loss: 0.4868 - accuracy: 0.7900 - val_loss: 0.4841 - val_accuracy: 0.8025
# Epoch 56/300
# 4/4 - 0s - loss: 0.4849 - accuracy: 0.7900 - val_loss: 0.4832 - val_accuracy: 0.8025
# Epoch 57/300
# 4/4 - 0s - loss: 0.4830 - accuracy: 0.7900 - val_loss: 0.4821 - val_accuracy: 0.8025
# Epoch 58/300
# 4/4 - 0s - loss: 0.4800 - accuracy: 0.7900 - val_loss: 0.4818 - val_accuracy: 0.8025
# Epoch 59/300
# 4/4 - 0s - loss: 0.4802 - accuracy: 0.7900 - val_loss: 0.4857 - val_accuracy: 0.8025
# Epoch 60/300
# 4/4 - 0s - loss: 0.4845 - accuracy: 0.7900 - val_loss: 0.4854 - val_accuracy: 0.8025
# Epoch 61/300
# 4/4 - 0s - loss: 0.4812 - accuracy: 0.7900 - val_loss: 0.4782 - val_accuracy: 0.8025
# Epoch 62/300
# 4/4 - 0s - loss: 0.4746 - accuracy: 0.7900 - val_loss: 0.4777 - val_accuracy: 0.8025
# Epoch 63/300
# 4/4 - 0s - loss: 0.4687 - accuracy: 0.7900 - val_loss: 0.4755 - val_accuracy: 0.8025
# Epoch 64/300
# 4/4 - 0s - loss: 0.4656 - accuracy: 0.7900 - val_loss: 0.4744 - val_accuracy: 0.8025
# Epoch 65/300
# 4/4 - 0s - loss: 0.4633 - accuracy: 0.7900 - val_loss: 0.4740 - val_accuracy: 0.8025
# Epoch 66/300
# 4/4 - 0s - loss: 0.4645 - accuracy: 0.7900 - val_loss: 0.4797 - val_accuracy: 0.8025
# Epoch 67/300
# 4/4 - 0s - loss: 0.4616 - accuracy: 0.7900 - val_loss: 0.4714 - val_accuracy: 0.8025
# Epoch 68/300
# 4/4 - 0s - loss: 0.4518 - accuracy: 0.7900 - val_loss: 0.4698 - val_accuracy: 0.8025
# Epoch 69/300
# 4/4 - 0s - loss: 0.4556 - accuracy: 0.7900 - val_loss: 0.4704 - val_accuracy: 0.8025
# Epoch 70/300
# 4/4 - 0s - loss: 0.4505 - accuracy: 0.7900 - val_loss: 0.4654 - val_accuracy: 0.8025
# Epoch 71/300
# 4/4 - 0s - loss: 0.4463 - accuracy: 0.7900 - val_loss: 0.4641 - val_accuracy: 0.8025
# Epoch 72/300
# 4/4 - 0s - loss: 0.4390 - accuracy: 0.7900 - val_loss: 0.4617 - val_accuracy: 0.8025
# Epoch 73/300
# 4/4 - 0s - loss: 0.4362 - accuracy: 0.7900 - val_loss: 0.4599 - val_accuracy: 0.8025
# Epoch 74/300
# 4/4 - 0s - loss: 0.4317 - accuracy: 0.7900 - val_loss: 0.4581 - val_accuracy: 0.8025
# Epoch 75/300
# 4/4 - 0s - loss: 0.4267 - accuracy: 0.7900 - val_loss: 0.4564 - val_accuracy: 0.8025
# Epoch 76/300
# 4/4 - 0s - loss: 0.4230 - accuracy: 0.7900 - val_loss: 0.4543 - val_accuracy: 0.8025
# Epoch 77/300
# 4/4 - 0s - loss: 0.4182 - accuracy: 0.7900 - val_loss: 0.4520 - val_accuracy: 0.8025
# Epoch 78/300
# 4/4 - 0s - loss: 0.4141 - accuracy: 0.7900 - val_loss: 0.4499 - val_accuracy: 0.8025
# Epoch 79/300
# 4/4 - 0s - loss: 0.4142 - accuracy: 0.7900 - val_loss: 0.4548 - val_accuracy: 0.8025
# Epoch 80/300
# 4/4 - 0s - loss: 0.4094 - accuracy: 0.7900 - val_loss: 0.4489 - val_accuracy: 0.8025
# Epoch 81/300
# 4/4 - 0s - loss: 0.4016 - accuracy: 0.7900 - val_loss: 0.4431 - val_accuracy: 0.8025
# Epoch 82/300
# 4/4 - 0s - loss: 0.3941 - accuracy: 0.7900 - val_loss: 0.4410 - val_accuracy: 0.8025
# Epoch 83/300
# 4/4 - 0s - loss: 0.3919 - accuracy: 0.7900 - val_loss: 0.4373 - val_accuracy: 0.8025
# Epoch 84/300
# 4/4 - 0s - loss: 0.3776 - accuracy: 0.7900 - val_loss: 0.4399 - val_accuracy: 0.8025
# Epoch 85/300
# 4/4 - 0s - loss: 0.3770 - accuracy: 0.7900 - val_loss: 0.4314 - val_accuracy: 0.8025
# Epoch 86/300
# 4/4 - 0s - loss: 0.3686 - accuracy: 0.7900 - val_loss: 0.4337 - val_accuracy: 0.8025
# Epoch 87/300
# 4/4 - 0s - loss: 0.3607 - accuracy: 0.7900 - val_loss: 0.4233 - val_accuracy: 0.8025
# Epoch 88/300
# 4/4 - 0s - loss: 0.3432 - accuracy: 0.8000 - val_loss: 0.4467 - val_accuracy: 0.8125
# Epoch 89/300
# 4/4 - 0s - loss: 0.3678 - accuracy: 0.9400 - val_loss: 0.4157 - val_accuracy: 0.8025
# Epoch 90/300
# 4/4 - 0s - loss: 0.3402 - accuracy: 0.8100 - val_loss: 0.4300 - val_accuracy: 0.8025
# Epoch 91/300
# 4/4 - 0s - loss: 0.3200 - accuracy: 0.8000 - val_loss: 0.4225 - val_accuracy: 0.8200
# Epoch 92/300
# 4/4 - 0s - loss: 0.3122 - accuracy: 0.9500 - val_loss: 0.4035 - val_accuracy: 0.8075
# Epoch 93/300
# 4/4 - 0s - loss: 0.3081 - accuracy: 0.8100 - val_loss: 0.4149 - val_accuracy: 0.8025
# Epoch 94/300
# 4/4 - 0s - loss: 0.3095 - accuracy: 0.8200 - val_loss: 0.3970 - val_accuracy: 0.8200
# Epoch 95/300
# 4/4 - 0s - loss: 0.2712 - accuracy: 0.9300 - val_loss: 0.3915 - val_accuracy: 0.8025
# Epoch 96/300
# 4/4 - 0s - loss: 0.2959 - accuracy: 0.8000 - val_loss: 0.3991 - val_accuracy: 0.8025
# Epoch 97/300
# 4/4 - 0s - loss: 0.2702 - accuracy: 0.8900 - val_loss: 0.4286 - val_accuracy: 0.8275
# Epoch 98/300
# 4/4 - 0s - loss: 0.2619 - accuracy: 0.9500 - val_loss: 0.3798 - val_accuracy: 0.8150
# Epoch 99/300
# 4/4 - 0s - loss: 0.2349 - accuracy: 0.9100 - val_loss: 0.3885 - val_accuracy: 0.8025
# Epoch 100/300
# 4/4 - 0s - loss: 0.2433 - accuracy: 0.8700 - val_loss: 0.3752 - val_accuracy: 0.8150
# Epoch 101/300
# 4/4 - 0s - loss: 0.2409 - accuracy: 0.9500 - val_loss: 0.4111 - val_accuracy: 0.8300
# Epoch 102/300
# 4/4 - 0s - loss: 0.2311 - accuracy: 0.9700 - val_loss: 0.3681 - val_accuracy: 0.8200
# Epoch 103/300
# 4/4 - 0s - loss: 0.2036 - accuracy: 0.9400 - val_loss: 0.3753 - val_accuracy: 0.8125
# Epoch 104/300
# 4/4 - 0s - loss: 0.2147 - accuracy: 0.9000 - val_loss: 0.3641 - val_accuracy: 0.8325
# Epoch 105/300
# 4/4 - 0s - loss: 0.2408 - accuracy: 0.8900 - val_loss: 0.4535 - val_accuracy: 0.7875
# Epoch 106/300
# 4/4 - 0s - loss: 0.2178 - accuracy: 0.9600 - val_loss: 0.3752 - val_accuracy: 0.8150
# Epoch 107/300
# 4/4 - 0s - loss: 0.2122 - accuracy: 0.9000 - val_loss: 0.4079 - val_accuracy: 0.8050
# Epoch 108/300
# 4/4 - 0s - loss: 0.1946 - accuracy: 0.9200 - val_loss: 0.3699 - val_accuracy: 0.8550
# Epoch 109/300
# 4/4 - 0s - loss: 0.1953 - accuracy: 0.9800 - val_loss: 0.4022 - val_accuracy: 0.8325
# Epoch 110/300
# 4/4 - 0s - loss: 0.1914 - accuracy: 0.9800 - val_loss: 0.3534 - val_accuracy: 0.8400
# Epoch 111/300
# 4/4 - 0s - loss: 0.1671 - accuracy: 0.9500 - val_loss: 0.3988 - val_accuracy: 0.8075
# Epoch 112/300
# 4/4 - 0s - loss: 0.2091 - accuracy: 0.9000 - val_loss: 0.4007 - val_accuracy: 0.8100
# Epoch 113/300
# 4/4 - 0s - loss: 0.1744 - accuracy: 0.9300 - val_loss: 0.3501 - val_accuracy: 0.8425
# Epoch 114/300
# 4/4 - 0s - loss: 0.1544 - accuracy: 0.9900 - val_loss: 0.3890 - val_accuracy: 0.8300
# Epoch 115/300
# 4/4 - 0s - loss: 0.1638 - accuracy: 0.9800 - val_loss: 0.3489 - val_accuracy: 0.8350
# Epoch 116/300
# 4/4 - 0s - loss: 0.1446 - accuracy: 0.9500 - val_loss: 0.3816 - val_accuracy: 0.8225
# Epoch 117/300
# 4/4 - 0s - loss: 0.1600 - accuracy: 0.9300 - val_loss: 0.3585 - val_accuracy: 0.8225
# Epoch 118/300
# 4/4 - 0s - loss: 0.1388 - accuracy: 0.9600 - val_loss: 0.3454 - val_accuracy: 0.8450
# Epoch 119/300
# 4/4 - 0s - loss: 0.1328 - accuracy: 0.9800 - val_loss: 0.3451 - val_accuracy: 0.8400
# Epoch 120/300
# 4/4 - 0s - loss: 0.1304 - accuracy: 0.9800 - val_loss: 0.3496 - val_accuracy: 0.8350
# Epoch 121/300
# 4/4 - 0s - loss: 0.1288 - accuracy: 0.9700 - val_loss: 0.3435 - val_accuracy: 0.8425
# Epoch 122/300
# 4/4 - 0s - loss: 0.1263 - accuracy: 0.9800 - val_loss: 0.3464 - val_accuracy: 0.8550
# Epoch 123/300
# 4/4 - 0s - loss: 0.1230 - accuracy: 0.9900 - val_loss: 0.3457 - val_accuracy: 0.8400
# Epoch 124/300
# 4/4 - 0s - loss: 0.1216 - accuracy: 0.9700 - val_loss: 0.3828 - val_accuracy: 0.8200
# Epoch 125/300
# 4/4 - 0s - loss: 0.1357 - accuracy: 0.9600 - val_loss: 0.3477 - val_accuracy: 0.8350
# Epoch 126/300
# 4/4 - 0s - loss: 0.1163 - accuracy: 0.9800 - val_loss: 0.3468 - val_accuracy: 0.8575
# Epoch 127/300
# 4/4 - 0s - loss: 0.1175 - accuracy: 0.9900 - val_loss: 0.3724 - val_accuracy: 0.8300
# Epoch 128/300
# 4/4 - 0s - loss: 0.1445 - accuracy: 0.9800 - val_loss: 0.3550 - val_accuracy: 0.8375
# Epoch 129/300
# 4/4 - 0s - loss: 0.1094 - accuracy: 0.9900 - val_loss: 0.3583 - val_accuracy: 0.8275
# Epoch 130/300
# 4/4 - 0s - loss: 0.1203 - accuracy: 0.9500 - val_loss: 0.3794 - val_accuracy: 0.8225
# Epoch 131/300
# 4/4 - 0s - loss: 0.1105 - accuracy: 0.9700 - val_loss: 0.3392 - val_accuracy: 0.8450
# Epoch 132/300
# 4/4 - 0s - loss: 0.1010 - accuracy: 0.9800 - val_loss: 0.3418 - val_accuracy: 0.8525
# Epoch 133/300
# 4/4 - 0s - loss: 0.1014 - accuracy: 0.9900 - val_loss: 0.3401 - val_accuracy: 0.8500
# Epoch 134/300
# 4/4 - 0s - loss: 0.1022 - accuracy: 0.9900 - val_loss: 0.3635 - val_accuracy: 0.8375
# Epoch 135/300
# 4/4 - 0s - loss: 0.1126 - accuracy: 0.9800 - val_loss: 0.3424 - val_accuracy: 0.8575
# Epoch 136/300
# 4/4 - 0s - loss: 0.0934 - accuracy: 0.9900 - val_loss: 0.3514 - val_accuracy: 0.8375
# Epoch 137/300
# 4/4 - 0s - loss: 0.0983 - accuracy: 0.9800 - val_loss: 0.3619 - val_accuracy: 0.8350
# Epoch 138/300
# 4/4 - 0s - loss: 0.0910 - accuracy: 0.9800 - val_loss: 0.3415 - val_accuracy: 0.8550
# Epoch 139/300
# 4/4 - 0s - loss: 0.0947 - accuracy: 0.9900 - val_loss: 0.3504 - val_accuracy: 0.8425
# Epoch 140/300
# 4/4 - 0s - loss: 0.0933 - accuracy: 0.9900 - val_loss: 0.3384 - val_accuracy: 0.8575
# Epoch 141/300
# 4/4 - 0s - loss: 0.0836 - accuracy: 0.9800 - val_loss: 0.3496 - val_accuracy: 0.8425
# Epoch 142/300
# 4/4 - 0s - loss: 0.0845 - accuracy: 0.9800 - val_loss: 0.3390 - val_accuracy: 0.8600
# Epoch 143/300
# 4/4 - 0s - loss: 0.0858 - accuracy: 0.9900 - val_loss: 0.3409 - val_accuracy: 0.8550
# Epoch 144/300
# 4/4 - 0s - loss: 0.0796 - accuracy: 0.9900 - val_loss: 0.3545 - val_accuracy: 0.8400
# Epoch 145/300
# 4/4 - 0s - loss: 0.0867 - accuracy: 0.9800 - val_loss: 0.3660 - val_accuracy: 0.8375
# Epoch 146/300
# 4/4 - 0s - loss: 0.0826 - accuracy: 0.9800 - val_loss: 0.3391 - val_accuracy: 0.8575
# Epoch 147/300
# 4/4 - 0s - loss: 0.0764 - accuracy: 0.9900 - val_loss: 0.3436 - val_accuracy: 0.8575
# Epoch 148/300
# 4/4 - 0s - loss: 0.0776 - accuracy: 0.9900 - val_loss: 0.3407 - val_accuracy: 0.8550
# Epoch 149/300
# 4/4 - 0s - loss: 0.0724 - accuracy: 0.9900 - val_loss: 0.3589 - val_accuracy: 0.8400
# Epoch 150/300
# 4/4 - 0s - loss: 0.0768 - accuracy: 0.9800 - val_loss: 0.3547 - val_accuracy: 0.8425
# Epoch 151/300
# 4/4 - 0s - loss: 0.0728 - accuracy: 0.9800 - val_loss: 0.3464 - val_accuracy: 0.8475
# Epoch 152/300
# 4/4 - 0s - loss: 0.0718 - accuracy: 0.9900 - val_loss: 0.3501 - val_accuracy: 0.8475
# Epoch 153/300
# 4/4 - 0s - loss: 0.0690 - accuracy: 0.9900 - val_loss: 0.3408 - val_accuracy: 0.8575
# Epoch 154/300
# 4/4 - 0s - loss: 0.0681 - accuracy: 0.9900 - val_loss: 0.3427 - val_accuracy: 0.8600
# Epoch 155/300
# 4/4 - 0s - loss: 0.0680 - accuracy: 0.9900 - val_loss: 0.3418 - val_accuracy: 0.8600
# Epoch 156/300
# 4/4 - 0s - loss: 0.0682 - accuracy: 0.9900 - val_loss: 0.3508 - val_accuracy: 0.8475
# Epoch 157/300
# 4/4 - 0s - loss: 0.0656 - accuracy: 0.9900 - val_loss: 0.3499 - val_accuracy: 0.8475
# Epoch 158/300
# 4/4 - 0s - loss: 0.0645 - accuracy: 0.9900 - val_loss: 0.3423 - val_accuracy: 0.8575
# Epoch 159/300
# 4/4 - 0s - loss: 0.0622 - accuracy: 0.9900 - val_loss: 0.3420 - val_accuracy: 0.8475
# Epoch 160/300
# 4/4 - 0s - loss: 0.0625 - accuracy: 0.9900 - val_loss: 0.3449 - val_accuracy: 0.8525
# Epoch 161/300
# 4/4 - 0s - loss: 0.0609 - accuracy: 0.9900 - val_loss: 0.3546 - val_accuracy: 0.8475
# Epoch 162/300
# 4/4 - 0s - loss: 0.0609 - accuracy: 0.9900 - val_loss: 0.3518 - val_accuracy: 0.8475
# Epoch 163/300
# 4/4 - 0s - loss: 0.0592 - accuracy: 0.9900 - val_loss: 0.3467 - val_accuracy: 0.8500
# Epoch 164/300
# 4/4 - 0s - loss: 0.0569 - accuracy: 0.9900 - val_loss: 0.3437 - val_accuracy: 0.8475
# Epoch 165/300
# 4/4 - 0s - loss: 0.0584 - accuracy: 0.9900 - val_loss: 0.3444 - val_accuracy: 0.8600
# Epoch 166/300
# 4/4 - 0s - loss: 0.0662 - accuracy: 0.9900 - val_loss: 0.3595 - val_accuracy: 0.8400
# Epoch 167/300
# 4/4 - 0s - loss: 0.0644 - accuracy: 0.9900 - val_loss: 0.3447 - val_accuracy: 0.8500
# Epoch 168/300
# 4/4 - 0s - loss: 0.0538 - accuracy: 0.9900 - val_loss: 0.3656 - val_accuracy: 0.8475
# Epoch 169/300
# 4/4 - 0s - loss: 0.0563 - accuracy: 0.9900 - val_loss: 0.3522 - val_accuracy: 0.8475
# Epoch 170/300
# 4/4 - 0s - loss: 0.0533 - accuracy: 0.9900 - val_loss: 0.3471 - val_accuracy: 0.8600
# Epoch 171/300
# 4/4 - 0s - loss: 0.0518 - accuracy: 0.9900 - val_loss: 0.3524 - val_accuracy: 0.8500
# Epoch 172/300
# 4/4 - 0s - loss: 0.0512 - accuracy: 0.9900 - val_loss: 0.3496 - val_accuracy: 0.8575
# Epoch 173/300
# 4/4 - 0s - loss: 0.0501 - accuracy: 0.9900 - val_loss: 0.3474 - val_accuracy: 0.8550
# Epoch 174/300
# 4/4 - 0s - loss: 0.0512 - accuracy: 0.9900 - val_loss: 0.3471 - val_accuracy: 0.8500
# Epoch 175/300
# 4/4 - 0s - loss: 0.0497 - accuracy: 0.9900 - val_loss: 0.3479 - val_accuracy: 0.8550
# Epoch 176/300
# 4/4 - 0s - loss: 0.0483 - accuracy: 0.9900 - val_loss: 0.3496 - val_accuracy: 0.8600
# Epoch 177/300
# 4/4 - 0s - loss: 0.0485 - accuracy: 0.9900 - val_loss: 0.3574 - val_accuracy: 0.8475
# Epoch 178/300
# 4/4 - 0s - loss: 0.0476 - accuracy: 0.9900 - val_loss: 0.3590 - val_accuracy: 0.8500
# Epoch 179/300
# 4/4 - 0s - loss: 0.0485 - accuracy: 0.9900 - val_loss: 0.3494 - val_accuracy: 0.8575
# Epoch 180/300
# 4/4 - 0s - loss: 0.0458 - accuracy: 0.9900 - val_loss: 0.3493 - val_accuracy: 0.8525
# Epoch 181/300
# 4/4 - 0s - loss: 0.0457 - accuracy: 0.9900 - val_loss: 0.3516 - val_accuracy: 0.8625
# Epoch 182/300
# 4/4 - 0s - loss: 0.0439 - accuracy: 0.9900 - val_loss: 0.3595 - val_accuracy: 0.8475
# Epoch 183/300
# 4/4 - 0s - loss: 0.0455 - accuracy: 0.9900 - val_loss: 0.3655 - val_accuracy: 0.8500
# Epoch 184/300
# 4/4 - 0s - loss: 0.0452 - accuracy: 0.9900 - val_loss: 0.3637 - val_accuracy: 0.8500
# Epoch 185/300
# 4/4 - 0s - loss: 0.0437 - accuracy: 0.9900 - val_loss: 0.3570 - val_accuracy: 0.8550
# Epoch 186/300
# 4/4 - 0s - loss: 0.0427 - accuracy: 0.9900 - val_loss: 0.3524 - val_accuracy: 0.8600
# Epoch 187/300
# 4/4 - 0s - loss: 0.0427 - accuracy: 0.9900 - val_loss: 0.3532 - val_accuracy: 0.8600
# Epoch 188/300
# 4/4 - 0s - loss: 0.0418 - accuracy: 0.9900 - val_loss: 0.3680 - val_accuracy: 0.8475
# Epoch 189/300
# 4/4 - 0s - loss: 0.0430 - accuracy: 0.9900 - val_loss: 0.3731 - val_accuracy: 0.8500
# Epoch 190/300
# 4/4 - 0s - loss: 0.0428 - accuracy: 0.9900 - val_loss: 0.3656 - val_accuracy: 0.8500
# Epoch 191/300
# 4/4 - 0s - loss: 0.0413 - accuracy: 0.9900 - val_loss: 0.3649 - val_accuracy: 0.8475
# Epoch 192/300
# 4/4 - 0s - loss: 0.0402 - accuracy: 0.9900 - val_loss: 0.3599 - val_accuracy: 0.8550
# Epoch 193/300
# 4/4 - 0s - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.3549 - val_accuracy: 0.8600
# Epoch 194/300
# 4/4 - 0s - loss: 0.0383 - accuracy: 0.9900 - val_loss: 0.3599 - val_accuracy: 0.8600
# Epoch 195/300
# 4/4 - 0s - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.8150
# Epoch 196/300
# 4/4 - 0s - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.8550
# Epoch 197/300
# 4/4 - 0s - loss: 0.0351 - accuracy: 0.9900 - val_loss: 0.3763 - val_accuracy: 0.8475
# Epoch 198/300
# 4/4 - 0s - loss: 0.0404 - accuracy: 0.9900 - val_loss: 0.4087 - val_accuracy: 0.8400
# Epoch 199/300
# 4/4 - 0s - loss: 0.0454 - accuracy: 0.9900 - val_loss: 0.3767 - val_accuracy: 0.8500
# Epoch 200/300
# 4/4 - 0s - loss: 0.0360 - accuracy: 0.9900 - val_loss: 0.3570 - val_accuracy: 0.8525
# Epoch 201/300
# 4/4 - 0s - loss: 0.0364 - accuracy: 0.9900 - val_loss: 0.3623 - val_accuracy: 0.8600
# Epoch 202/300
# 4/4 - 0s - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.3582 - val_accuracy: 0.8525
# Epoch 203/300
# 4/4 - 0s - loss: 0.0335 - accuracy: 0.9900 - val_loss: 0.3651 - val_accuracy: 0.8575
# Epoch 204/300
# 4/4 - 0s - loss: 0.0351 - accuracy: 0.9900 - val_loss: 0.3759 - val_accuracy: 0.8475
# Epoch 205/300
# 4/4 - 0s - loss: 0.0348 - accuracy: 0.9900 - val_loss: 0.3658 - val_accuracy: 0.8600
# Epoch 206/300
# 4/4 - 0s - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.3645 - val_accuracy: 0.8625
# Epoch 207/300
# 4/4 - 0s - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.3693 - val_accuracy: 0.8550
# Epoch 208/300
# 4/4 - 0s - loss: 0.0324 - accuracy: 0.9900 - val_loss: 0.3729 - val_accuracy: 0.8525
# Epoch 209/300
# 4/4 - 0s - loss: 0.0324 - accuracy: 0.9900 - val_loss: 0.3699 - val_accuracy: 0.8550
# Epoch 210/300
# 4/4 - 0s - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.3631 - val_accuracy: 0.8600
# Epoch 211/300
# 4/4 - 0s - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.3649 - val_accuracy: 0.8625
# Epoch 212/300
# 4/4 - 0s - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.3650 - val_accuracy: 0.8625
# Epoch 213/300
# 4/4 - 0s - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.3635 - val_accuracy: 0.8550
# Epoch 214/300
# 4/4 - 0s - loss: 0.0310 - accuracy: 0.9900 - val_loss: 0.3658 - val_accuracy: 0.8600
# Epoch 215/300
# 4/4 - 0s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.3651 - val_accuracy: 0.8525
# Epoch 216/300
# 4/4 - 0s - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.3650 - val_accuracy: 0.8550
# Epoch 217/300
# 4/4 - 0s - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.3756 - val_accuracy: 0.8525
# Epoch 218/300
# 4/4 - 0s - loss: 0.0305 - accuracy: 0.9900 - val_loss: 0.3888 - val_accuracy: 0.8450
# Epoch 219/300
# 4/4 - 0s - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.3706 - val_accuracy: 0.8625
# Epoch 220/300
# 4/4 - 0s - loss: 0.0276 - accuracy: 0.9900 - val_loss: 0.3688 - val_accuracy: 0.8625
# Epoch 221/300
# 4/4 - 0s - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.3726 - val_accuracy: 0.8625
# Epoch 222/300
# 4/4 - 0s - loss: 0.0277 - accuracy: 0.9900 - val_loss: 0.3669 - val_accuracy: 0.8475
# Epoch 223/300
# 4/4 - 0s - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.3682 - val_accuracy: 0.8475
# Epoch 224/300
# 4/4 - 0s - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.3679 - val_accuracy: 0.8475
# Epoch 225/300
# 4/4 - 0s - loss: 0.0251 - accuracy: 0.9900 - val_loss: 0.3850 - val_accuracy: 0.8525
# Epoch 226/300
# 4/4 - 0s - loss: 0.0284 - accuracy: 0.9900 - val_loss: 0.3983 - val_accuracy: 0.8500
# Epoch 227/300
# 4/4 - 0s - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.3905 - val_accuracy: 0.8525
# Epoch 228/300
# 4/4 - 0s - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.3715 - val_accuracy: 0.8550
# Epoch 229/300
# 4/4 - 0s - loss: 0.0244 - accuracy: 0.9900 - val_loss: 0.3701 - val_accuracy: 0.8475
# Epoch 230/300
# 4/4 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.3717 - val_accuracy: 0.8575
# Epoch 231/300
# 4/4 - 0s - loss: 0.0249 - accuracy: 0.9900 - val_loss: 0.3791 - val_accuracy: 0.8625
# Epoch 232/300
# 4/4 - 0s - loss: 0.0234 - accuracy: 0.9900 - val_loss: 0.3723 - val_accuracy: 0.8575
# Epoch 233/300
# 4/4 - 0s - loss: 0.0236 - accuracy: 0.9900 - val_loss: 0.3735 - val_accuracy: 0.8550
# Epoch 234/300
# 4/4 - 0s - loss: 0.0230 - accuracy: 0.9900 - val_loss: 0.3757 - val_accuracy: 0.8625
# Epoch 235/300
# 4/4 - 0s - loss: 0.0225 - accuracy: 0.9900 - val_loss: 0.3836 - val_accuracy: 0.8600
# Epoch 236/300
# 4/4 - 0s - loss: 0.0233 - accuracy: 0.9900 - val_loss: 0.3825 - val_accuracy: 0.8600
# Epoch 237/300
# 4/4 - 0s - loss: 0.0224 - accuracy: 0.9900 - val_loss: 0.3785 - val_accuracy: 0.8625
# Epoch 238/300
# 4/4 - 0s - loss: 0.0218 - accuracy: 0.9900 - val_loss: 0.3760 - val_accuracy: 0.8575
# Epoch 239/300
# 4/4 - 0s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.3759 - val_accuracy: 0.8550
# Epoch 240/300
# 4/4 - 0s - loss: 0.0219 - accuracy: 0.9900 - val_loss: 0.3805 - val_accuracy: 0.8625
# Epoch 241/300
# 4/4 - 0s - loss: 0.0216 - accuracy: 0.9900 - val_loss: 0.3837 - val_accuracy: 0.8600
# Epoch 242/300
# 4/4 - 0s - loss: 0.0218 - accuracy: 0.9900 - val_loss: 0.3880 - val_accuracy: 0.8550
# Epoch 243/300
# 4/4 - 0s - loss: 0.0215 - accuracy: 0.9900 - val_loss: 0.3842 - val_accuracy: 0.8625
# Epoch 244/300
# 4/4 - 0s - loss: 0.0209 - accuracy: 0.9900 - val_loss: 0.3833 - val_accuracy: 0.8625
# Epoch 245/300
# 4/4 - 0s - loss: 0.0216 - accuracy: 0.9900 - val_loss: 0.3944 - val_accuracy: 0.8550
# Epoch 246/300
# 4/4 - 0s - loss: 0.0215 - accuracy: 0.9900 - val_loss: 0.3867 - val_accuracy: 0.8600
# Epoch 247/300
# 4/4 - 0s - loss: 0.0207 - accuracy: 0.9900 - val_loss: 0.3805 - val_accuracy: 0.8525
# Epoch 248/300
# 4/4 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.8575
# Epoch 249/300
# 4/4 - 0s - loss: 0.0206 - accuracy: 0.9900 - val_loss: 0.4013 - val_accuracy: 0.8525
# Epoch 250/300
# 4/4 - 0s - loss: 0.0220 - accuracy: 0.9900 - val_loss: 0.3961 - val_accuracy: 0.8575
# Epoch 251/300
# 4/4 - 0s - loss: 0.0203 - accuracy: 0.9900 - val_loss: 0.3805 - val_accuracy: 0.8450
# Epoch 252/300
# 4/4 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.8475
# Epoch 253/300
# 4/4 - 0s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.3835 - val_accuracy: 0.8525
# Epoch 254/300
# 4/4 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.8625
# Epoch 255/300
# 4/4 - 0s - loss: 0.0183 - accuracy: 0.9900 - val_loss: 0.3883 - val_accuracy: 0.8625
# Epoch 256/300
# 4/4 - 0s - loss: 0.0183 - accuracy: 0.9900 - val_loss: 0.3874 - val_accuracy: 0.8600
# Epoch 257/300
# 4/4 - 0s - loss: 0.0180 - accuracy: 0.9900 - val_loss: 0.3914 - val_accuracy: 0.8600
# Epoch 258/300
# 4/4 - 0s - loss: 0.0174 - accuracy: 0.9900 - val_loss: 0.3855 - val_accuracy: 0.8525
# Epoch 259/300
# 4/4 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.8500
# Epoch 260/300
# 4/4 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.8200
# Epoch 261/300
# 4/4 - 0s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.3939 - val_accuracy: 0.8225
# Epoch 262/300
# 4/4 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.3988 - val_accuracy: 0.8575
# Epoch 263/300
# 4/4 - 0s - loss: 0.0223 - accuracy: 0.9900 - val_loss: 0.4411 - val_accuracy: 0.8475
# Epoch 264/300
# 4/4 - 0s - loss: 0.0225 - accuracy: 0.9900 - val_loss: 0.4158 - val_accuracy: 0.8500
# Epoch 265/300
# 4/4 - 0s - loss: 0.0177 - accuracy: 0.9900 - val_loss: 0.3905 - val_accuracy: 0.8525
# Epoch 266/300
# 4/4 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.3881 - val_accuracy: 0.8400
# Epoch 267/300
# 4/4 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.3884 - val_accuracy: 0.8425
# Epoch 268/300
# 4/4 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.3889 - val_accuracy: 0.8450
# Epoch 269/300
# 4/4 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.4230 - val_accuracy: 0.8175
# Epoch 270/300
# 4/4 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.3955 - val_accuracy: 0.8500
# Epoch 271/300
# 4/4 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.8575
# Epoch 272/300
# 4/4 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4237 - val_accuracy: 0.8500
# Epoch 273/300
# 4/4 - 0s - loss: 0.0180 - accuracy: 0.9900 - val_loss: 0.4263 - val_accuracy: 0.8500
# Epoch 274/300
# 4/4 - 0s - loss: 0.0168 - accuracy: 0.9900 - val_loss: 0.4028 - val_accuracy: 0.8575
# Epoch 275/300
# 4/4 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3931 - val_accuracy: 0.8500
# Epoch 276/300
# 4/4 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.3930 - val_accuracy: 0.8475
# Epoch 277/300
# 4/4 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.8475
# Epoch 278/300
# 4/4 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.8500
# Epoch 279/300
# 4/4 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.3947 - val_accuracy: 0.8475
# Epoch 280/300
# 4/4 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.3984 - val_accuracy: 0.8500
# Epoch 281/300
# 4/4 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4005 - val_accuracy: 0.8575
# Epoch 282/300
# 4/4 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.3956 - val_accuracy: 0.8475
# Epoch 283/300
# 4/4 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.8025
# Epoch 284/300
# 4/4 - 0s - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.4169 - val_accuracy: 0.8275
# Epoch 285/300
# 4/4 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.4197 - val_accuracy: 0.8575
# Epoch 286/300
# 4/4 - 0s - loss: 0.0145 - accuracy: 0.9900 - val_loss: 0.4660 - val_accuracy: 0.8450
# Epoch 287/300
# 4/4 - 0s - loss: 0.0200 - accuracy: 0.9900 - val_loss: 0.4520 - val_accuracy: 0.8500
# Epoch 288/300
# 4/4 - 0s - loss: 0.0164 - accuracy: 0.9900 - val_loss: 0.4137 - val_accuracy: 0.8525
# Epoch 289/300
# 4/4 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.8475
# Epoch 290/300
# 4/4 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4003 - val_accuracy: 0.8475
# Epoch 291/300
# 4/4 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.8500
# Epoch 292/300
# 4/4 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.8575
# Epoch 293/300
# 4/4 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.8500
# Epoch 294/300
# 4/4 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.8525
# Epoch 295/300
# 4/4 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4126 - val_accuracy: 0.8525
# Epoch 296/300
# 4/4 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 0.8550
# Epoch 297/300
# 4/4 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.8475
# Epoch 298/300
# 4/4 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4055 - val_accuracy: 0.8475
# Epoch 299/300
# 4/4 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4105 - val_accuracy: 0.8575
# Epoch 300/300
# 4/4 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.8575

# %% [markdown]
# ## Specialized Classifiers

# %%
prop_text = prop_data['text'].tolist()
prop_labels = prop_data['vague'].tolist()
speechact_text = speechact_data['text'].tolist()
speechact_labels = speechact_data['vague'].tolist()

prop_test_size = 0.5
speechact_test_size = 0.1

# %%
prop_train, prop_test, prop_label_train, prop_label_test = split_data(prop_text, prop_labels, prop_test_size)
speechact_train, speechact_test, speechact_label_train, speechact_label_test = split_data(speechact_text, speechact_labels, speechact_test_size)

# %%
proptok = Tokenizer(oov_token="<OOV>")
proptok.fit_on_texts(prop_train)
prop_word_index = proptok.word_index
prop_vocab_size = len(prop_word_index) + 1

speechacttok = Tokenizer(oov_token="<OOV>")
speechacttok.fit_on_texts(speechact_train)
speechact_word_index = speechacttok.word_index
speechact_vocab_size = len(speechact_word_index) + 1

# %%
prop_train_padded, prop_test_padded = make_sequences(proptok, prop_train, prop_test)
speechact_train_padded, speechact_test_padded = make_sequences(speechacttok, speechact_train, speechact_test)

# %%
prop_train_padded.shape
# Out:
# (200, 200)

# %% [markdown]
# ## Prop

# %%
prop_embedding_dim = 128

prop_model = tf.keras.Sequential([
        tf.keras.layers.Embedding(prop_vocab_size, prop_embedding_dim, input_length = max_length, name = 'Pembed'),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(256, activation = 'sigmoid'),
        tf.keras.layers.Dense(1, activation = 'sigmoid')
    ])

prop_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

prop_model.summary()
prop_n_epochs = 100

prop_history = prop_model.fit(prop_train_padded, prop_label_train, epochs = prop_n_epochs, 
                              validation_data = (prop_test_padded, prop_label_test), verbose = 2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Pembed (Embedding)           (None, 200, 128)          64896
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 98,177
# Trainable params: 98,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 - 0s - loss: 0.7016 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5150
# Epoch 2/100
# 7/7 - 0s - loss: 0.7056 - accuracy: 0.4850 - val_loss: 0.6967 - val_accuracy: 0.5150
# Epoch 3/100
# 7/7 - 0s - loss: 0.7001 - accuracy: 0.4950 - val_loss: 0.6954 - val_accuracy: 0.4850
# Epoch 4/100
# 7/7 - 0s - loss: 0.6931 - accuracy: 0.5150 - val_loss: 0.6984 - val_accuracy: 0.4850
# Epoch 5/100
# 7/7 - 0s - loss: 0.6947 - accuracy: 0.5150 - val_loss: 0.6953 - val_accuracy: 0.4850
# Epoch 6/100
# 7/7 - 0s - loss: 0.6933 - accuracy: 0.5150 - val_loss: 0.6950 - val_accuracy: 0.4850
# Epoch 7/100
# 7/7 - 0s - loss: 0.6919 - accuracy: 0.5150 - val_loss: 0.6929 - val_accuracy: 0.4850
# Epoch 8/100
# 7/7 - 0s - loss: 0.6920 - accuracy: 0.5150 - val_loss: 0.6925 - val_accuracy: 0.4850
# Epoch 9/100
# 7/7 - 0s - loss: 0.6925 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.4850
# Epoch 10/100
# 7/7 - 0s - loss: 0.6916 - accuracy: 0.5150 - val_loss: 0.6922 - val_accuracy: 0.4850
# Epoch 11/100
# 7/7 - 0s - loss: 0.6941 - accuracy: 0.5150 - val_loss: 0.6932 - val_accuracy: 0.4850
# Epoch 12/100
# 7/7 - 0s - loss: 0.6904 - accuracy: 0.5300 - val_loss: 0.6908 - val_accuracy: 0.5150
# Epoch 13/100
# 7/7 - 0s - loss: 0.6957 - accuracy: 0.4850 - val_loss: 0.6911 - val_accuracy: 0.5150
# Epoch 14/100
# 7/7 - 0s - loss: 0.6932 - accuracy: 0.5100 - val_loss: 0.6911 - val_accuracy: 0.4850
# Epoch 15/100
# 7/7 - 0s - loss: 0.6887 - accuracy: 0.5150 - val_loss: 0.6921 - val_accuracy: 0.4850
# Epoch 16/100
# 7/7 - 0s - loss: 0.6869 - accuracy: 0.5450 - val_loss: 0.6888 - val_accuracy: 0.5800
# Epoch 17/100
# 7/7 - 0s - loss: 0.6904 - accuracy: 0.5050 - val_loss: 0.6878 - val_accuracy: 0.5150
# Epoch 18/100
# 7/7 - 0s - loss: 0.6850 - accuracy: 0.5450 - val_loss: 0.6884 - val_accuracy: 0.4850
# Epoch 19/100
# 7/7 - 0s - loss: 0.6835 - accuracy: 0.5150 - val_loss: 0.6919 - val_accuracy: 0.4850
# Epoch 20/100
# 7/7 - 0s - loss: 0.6831 - accuracy: 0.5150 - val_loss: 0.6890 - val_accuracy: 0.4850
# Epoch 21/100
# 7/7 - 0s - loss: 0.6769 - accuracy: 0.6000 - val_loss: 0.6824 - val_accuracy: 0.6050
# Epoch 22/100
# 7/7 - 0s - loss: 0.6764 - accuracy: 0.7200 - val_loss: 0.6809 - val_accuracy: 0.7050
# Epoch 23/100
# 7/7 - 0s - loss: 0.6738 - accuracy: 0.7250 - val_loss: 0.6789 - val_accuracy: 0.7300
# Epoch 24/100
# 7/7 - 0s - loss: 0.6728 - accuracy: 0.6400 - val_loss: 0.6782 - val_accuracy: 0.5850
# Epoch 25/100
# 7/7 - 0s - loss: 0.6676 - accuracy: 0.6850 - val_loss: 0.6744 - val_accuracy: 0.5500
# Epoch 26/100
# 7/7 - 0s - loss: 0.6633 - accuracy: 0.7000 - val_loss: 0.6759 - val_accuracy: 0.5000
# Epoch 27/100
# 7/7 - 0s - loss: 0.6549 - accuracy: 0.6100 - val_loss: 0.6699 - val_accuracy: 0.7600
# Epoch 28/100
# 7/7 - 0s - loss: 0.6502 - accuracy: 0.8150 - val_loss: 0.6651 - val_accuracy: 0.6350
# Epoch 29/100
# 7/7 - 0s - loss: 0.6480 - accuracy: 0.6750 - val_loss: 0.6614 - val_accuracy: 0.6900
# Epoch 30/100
# 7/7 - 0s - loss: 0.6369 - accuracy: 0.8100 - val_loss: 0.6616 - val_accuracy: 0.6150
# Epoch 31/100
# 7/7 - 0s - loss: 0.6374 - accuracy: 0.6050 - val_loss: 0.6706 - val_accuracy: 0.4850
# Epoch 32/100
# 7/7 - 0s - loss: 0.6336 - accuracy: 0.6550 - val_loss: 0.6496 - val_accuracy: 0.7050
# Epoch 33/100
# 7/7 - 0s - loss: 0.6158 - accuracy: 0.8800 - val_loss: 0.6503 - val_accuracy: 0.6700
# Epoch 34/100
# 7/7 - 0s - loss: 0.6126 - accuracy: 0.7300 - val_loss: 0.6459 - val_accuracy: 0.6750
# Epoch 35/100
# 7/7 - 0s - loss: 0.6029 - accuracy: 0.8550 - val_loss: 0.6367 - val_accuracy: 0.7000
# Epoch 36/100
# 7/7 - 0s - loss: 0.5920 - accuracy: 0.8100 - val_loss: 0.6350 - val_accuracy: 0.7900
# Epoch 37/100
# 7/7 - 0s - loss: 0.5823 - accuracy: 0.9200 - val_loss: 0.6270 - val_accuracy: 0.7700
# Epoch 38/100
# 7/7 - 0s - loss: 0.5716 - accuracy: 0.9050 - val_loss: 0.6212 - val_accuracy: 0.7700
# Epoch 39/100
# 7/7 - 0s - loss: 0.5631 - accuracy: 0.8850 - val_loss: 0.6158 - val_accuracy: 0.7750
# Epoch 40/100
# 7/7 - 0s - loss: 0.5537 - accuracy: 0.9000 - val_loss: 0.6212 - val_accuracy: 0.6750
# Epoch 41/100
# 7/7 - 0s - loss: 0.5464 - accuracy: 0.8650 - val_loss: 0.6051 - val_accuracy: 0.7850
# Epoch 42/100
# 7/7 - 0s - loss: 0.5316 - accuracy: 0.8950 - val_loss: 0.5979 - val_accuracy: 0.7750
# Epoch 43/100
# 7/7 - 0s - loss: 0.5309 - accuracy: 0.8850 - val_loss: 0.6008 - val_accuracy: 0.7800
# Epoch 44/100
# 7/7 - 0s - loss: 0.5092 - accuracy: 0.9150 - val_loss: 0.5853 - val_accuracy: 0.7550
# Epoch 45/100
# 7/7 - 0s - loss: 0.5078 - accuracy: 0.8050 - val_loss: 0.5807 - val_accuracy: 0.7250
# Epoch 46/100
# 7/7 - 0s - loss: 0.4956 - accuracy: 0.8900 - val_loss: 0.5997 - val_accuracy: 0.6350
# Epoch 47/100
# 7/7 - 0s - loss: 0.4818 - accuracy: 0.8950 - val_loss: 0.5673 - val_accuracy: 0.7450
# Epoch 48/100
# 7/7 - 0s - loss: 0.4662 - accuracy: 0.8500 - val_loss: 0.5610 - val_accuracy: 0.7650
# Epoch 49/100
# 7/7 - 0s - loss: 0.4610 - accuracy: 0.9050 - val_loss: 0.5769 - val_accuracy: 0.7200
# Epoch 50/100
# 7/7 - 0s - loss: 0.4443 - accuracy: 0.9250 - val_loss: 0.5492 - val_accuracy: 0.7450
# Epoch 51/100
# 7/7 - 0s - loss: 0.4303 - accuracy: 0.9200 - val_loss: 0.5443 - val_accuracy: 0.7850
# Epoch 52/100
# 7/7 - 0s - loss: 0.4160 - accuracy: 0.9200 - val_loss: 0.5393 - val_accuracy: 0.7850
# Epoch 53/100
# 7/7 - 0s - loss: 0.4032 - accuracy: 0.9200 - val_loss: 0.5308 - val_accuracy: 0.7750
# Epoch 54/100
# 7/7 - 0s - loss: 0.3922 - accuracy: 0.9250 - val_loss: 0.5289 - val_accuracy: 0.7850
# Epoch 55/100
# 7/7 - 0s - loss: 0.3863 - accuracy: 0.9300 - val_loss: 0.5233 - val_accuracy: 0.7850
# Epoch 56/100
# 7/7 - 0s - loss: 0.3776 - accuracy: 0.9000 - val_loss: 0.5142 - val_accuracy: 0.7700
# Epoch 57/100
# 7/7 - 0s - loss: 0.3600 - accuracy: 0.9400 - val_loss: 0.5169 - val_accuracy: 0.8100
# Epoch 58/100
# 7/7 - 0s - loss: 0.3500 - accuracy: 0.9500 - val_loss: 0.5050 - val_accuracy: 0.7800
# Epoch 59/100
# 7/7 - 0s - loss: 0.3397 - accuracy: 0.9400 - val_loss: 0.5016 - val_accuracy: 0.7900
# Epoch 60/100
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.9400 - val_loss: 0.4946 - val_accuracy: 0.7750
# Epoch 61/100
# 7/7 - 0s - loss: 0.3195 - accuracy: 0.9400 - val_loss: 0.4956 - val_accuracy: 0.7850
# Epoch 62/100
# 7/7 - 0s - loss: 0.3130 - accuracy: 0.9500 - val_loss: 0.4879 - val_accuracy: 0.7850
# Epoch 63/100
# 7/7 - 0s - loss: 0.3016 - accuracy: 0.9500 - val_loss: 0.4824 - val_accuracy: 0.7900
# Epoch 64/100
# 7/7 - 0s - loss: 0.2921 - accuracy: 0.9500 - val_loss: 0.4820 - val_accuracy: 0.7800
# Epoch 65/100
# 7/7 - 0s - loss: 0.2902 - accuracy: 0.9650 - val_loss: 0.4765 - val_accuracy: 0.7950
# Epoch 66/100
# 7/7 - 0s - loss: 0.2960 - accuracy: 0.9000 - val_loss: 0.4719 - val_accuracy: 0.7800
# Epoch 67/100
# 7/7 - 0s - loss: 0.2819 - accuracy: 0.9650 - val_loss: 0.4914 - val_accuracy: 0.7900
# Epoch 68/100
# 7/7 - 0s - loss: 0.2603 - accuracy: 0.9600 - val_loss: 0.4691 - val_accuracy: 0.7550
# Epoch 69/100
# 7/7 - 0s - loss: 0.2545 - accuracy: 0.9400 - val_loss: 0.4704 - val_accuracy: 0.8000
# Epoch 70/100
# 7/7 - 0s - loss: 0.2452 - accuracy: 0.9650 - val_loss: 0.4639 - val_accuracy: 0.8000
# Epoch 71/100
# 7/7 - 0s - loss: 0.2454 - accuracy: 0.9350 - val_loss: 0.4585 - val_accuracy: 0.7950
# Epoch 72/100
# 7/7 - 0s - loss: 0.2339 - accuracy: 0.9700 - val_loss: 0.4754 - val_accuracy: 0.8050
# Epoch 73/100
# 7/7 - 0s - loss: 0.2273 - accuracy: 0.9650 - val_loss: 0.4541 - val_accuracy: 0.7850
# Epoch 74/100
# 7/7 - 0s - loss: 0.2255 - accuracy: 0.9700 - val_loss: 0.4683 - val_accuracy: 0.8100
# Epoch 75/100
# 7/7 - 0s - loss: 0.2112 - accuracy: 0.9800 - val_loss: 0.4498 - val_accuracy: 0.8000
# Epoch 76/100
# 7/7 - 0s - loss: 0.2112 - accuracy: 0.9450 - val_loss: 0.4515 - val_accuracy: 0.8000
# Epoch 77/100
# 7/7 - 0s - loss: 0.2003 - accuracy: 0.9800 - val_loss: 0.4476 - val_accuracy: 0.7950
# Epoch 78/100
# 7/7 - 0s - loss: 0.2010 - accuracy: 0.9500 - val_loss: 0.4449 - val_accuracy: 0.8000
# Epoch 79/100
# 7/7 - 0s - loss: 0.1907 - accuracy: 0.9700 - val_loss: 0.4761 - val_accuracy: 0.7950
# Epoch 80/100
# 7/7 - 0s - loss: 0.1907 - accuracy: 0.9700 - val_loss: 0.4420 - val_accuracy: 0.8000
# Epoch 81/100
# 7/7 - 0s - loss: 0.1807 - accuracy: 0.9650 - val_loss: 0.4462 - val_accuracy: 0.8000
# Epoch 82/100
# 7/7 - 0s - loss: 0.1783 - accuracy: 0.9800 - val_loss: 0.4517 - val_accuracy: 0.8200
# Epoch 83/100
# 7/7 - 0s - loss: 0.1688 - accuracy: 0.9700 - val_loss: 0.4383 - val_accuracy: 0.7950
# Epoch 84/100
# 7/7 - 0s - loss: 0.1707 - accuracy: 0.9700 - val_loss: 0.4531 - val_accuracy: 0.8100
# Epoch 85/100
# 7/7 - 0s - loss: 0.1610 - accuracy: 0.9750 - val_loss: 0.4382 - val_accuracy: 0.7900
# Epoch 86/100
# 7/7 - 0s - loss: 0.1557 - accuracy: 0.9700 - val_loss: 0.4372 - val_accuracy: 0.7950
# Epoch 87/100
# 7/7 - 0s - loss: 0.1502 - accuracy: 0.9750 - val_loss: 0.4377 - val_accuracy: 0.7950
# Epoch 88/100
# 7/7 - 0s - loss: 0.1461 - accuracy: 0.9750 - val_loss: 0.4455 - val_accuracy: 0.8100
# Epoch 89/100
# 7/7 - 0s - loss: 0.1436 - accuracy: 0.9750 - val_loss: 0.4347 - val_accuracy: 0.7900
# Epoch 90/100
# 7/7 - 0s - loss: 0.1438 - accuracy: 0.9700 - val_loss: 0.4453 - val_accuracy: 0.8100
# Epoch 91/100
# 7/7 - 0s - loss: 0.1369 - accuracy: 0.9800 - val_loss: 0.4393 - val_accuracy: 0.8050
# Epoch 92/100
# 7/7 - 0s - loss: 0.1325 - accuracy: 0.9800 - val_loss: 0.4347 - val_accuracy: 0.7900
# Epoch 93/100
# 7/7 - 0s - loss: 0.1366 - accuracy: 0.9750 - val_loss: 0.4344 - val_accuracy: 0.7900
# Epoch 94/100
# 7/7 - 0s - loss: 0.1231 - accuracy: 0.9800 - val_loss: 0.4531 - val_accuracy: 0.7950
# Epoch 95/100
# 7/7 - 0s - loss: 0.1237 - accuracy: 0.9850 - val_loss: 0.4360 - val_accuracy: 0.7900
# Epoch 96/100
# 7/7 - 0s - loss: 0.1269 - accuracy: 0.9700 - val_loss: 0.4356 - val_accuracy: 0.7950
# Epoch 97/100
# 7/7 - 0s - loss: 0.1179 - accuracy: 0.9850 - val_loss: 0.4658 - val_accuracy: 0.8000
# Epoch 98/100
# 7/7 - 0s - loss: 0.1161 - accuracy: 0.9850 - val_loss: 0.4346 - val_accuracy: 0.7950
# Epoch 99/100
# 7/7 - 0s - loss: 0.1121 - accuracy: 0.9800 - val_loss: 0.4411 - val_accuracy: 0.7950
# Epoch 100/100
# 7/7 - 0s - loss: 0.1084 - accuracy: 0.9850 - val_loss: 0.4386 - val_accuracy: 0.7950

# %% [markdown]
# ## Speech act

# %%
speechact_embedding_dim =500

speechact_model = tf.keras.Sequential([
        tf.keras.layers.Embedding(speechact_vocab_size, speechact_embedding_dim, input_length = max_length, name = 'SAembed'),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(64, activation = 'sigmoid'),
        tf.keras.layers.Dense(1, activation = 'sigmoid')
    ])

speechact_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

speechact_model.summary()
speechact_n_epochs = 100

speechact_history = speechact_model.fit(speechact_train_padded, speechact_label_train, 
                                        epochs = speechact_n_epochs, 
                                        validation_data = (speechact_test_padded, speechact_label_test), 
                                        verbose = 2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# SAembed (Embedding)          (None, 200, 500)          95500
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                32064
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 127,629
# Trainable params: 127,629
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 - 0s - loss: 0.6975 - accuracy: 0.4444 - val_loss: 0.6930 - val_accuracy: 0.6000
# Epoch 2/100
# 3/3 - 0s - loss: 0.6943 - accuracy: 0.4222 - val_loss: 0.6980 - val_accuracy: 0.4000
# Epoch 3/100
# 3/3 - 0s - loss: 0.6943 - accuracy: 0.5111 - val_loss: 0.7015 - val_accuracy: 0.4000
# Epoch 4/100
# 3/3 - 0s - loss: 0.6928 - accuracy: 0.5111 - val_loss: 0.7008 - val_accuracy: 0.4000
# Epoch 5/100
# 3/3 - 0s - loss: 0.6927 - accuracy: 0.5111 - val_loss: 0.6992 - val_accuracy: 0.4000
# Epoch 6/100
# 3/3 - 0s - loss: 0.6926 - accuracy: 0.5111 - val_loss: 0.6974 - val_accuracy: 0.4000
# Epoch 7/100
# 3/3 - 0s - loss: 0.6925 - accuracy: 0.5111 - val_loss: 0.6962 - val_accuracy: 0.4000
# Epoch 8/100
# 3/3 - 0s - loss: 0.6925 - accuracy: 0.5111 - val_loss: 0.6972 - val_accuracy: 0.4000
# Epoch 9/100
# 3/3 - 0s - loss: 0.6923 - accuracy: 0.5111 - val_loss: 0.6964 - val_accuracy: 0.4000
# Epoch 10/100
# 3/3 - 0s - loss: 0.6922 - accuracy: 0.5111 - val_loss: 0.6962 - val_accuracy: 0.4000
# Epoch 11/100
# 3/3 - 0s - loss: 0.6919 - accuracy: 0.5111 - val_loss: 0.6960 - val_accuracy: 0.4000
# Epoch 12/100
# 3/3 - 0s - loss: 0.6918 - accuracy: 0.5111 - val_loss: 0.6957 - val_accuracy: 0.4000
# Epoch 13/100
# 3/3 - 0s - loss: 0.6918 - accuracy: 0.5111 - val_loss: 0.6940 - val_accuracy: 0.4000
# Epoch 14/100
# 3/3 - 0s - loss: 0.6915 - accuracy: 0.5111 - val_loss: 0.6946 - val_accuracy: 0.4000
# Epoch 15/100
# 3/3 - 0s - loss: 0.6914 - accuracy: 0.5111 - val_loss: 0.6943 - val_accuracy: 0.4000
# Epoch 16/100
# 3/3 - 0s - loss: 0.6911 - accuracy: 0.5111 - val_loss: 0.6955 - val_accuracy: 0.4000
# Epoch 17/100
# 3/3 - 0s - loss: 0.6915 - accuracy: 0.5111 - val_loss: 0.6976 - val_accuracy: 0.4000
# Epoch 18/100
# 3/3 - 0s - loss: 0.6903 - accuracy: 0.5111 - val_loss: 0.6964 - val_accuracy: 0.4000
# Epoch 19/100
# 3/3 - 0s - loss: 0.6905 - accuracy: 0.5111 - val_loss: 0.6966 - val_accuracy: 0.4000
# Epoch 20/100
# 3/3 - 0s - loss: 0.6898 - accuracy: 0.5111 - val_loss: 0.6945 - val_accuracy: 0.4000
# Epoch 21/100
# 3/3 - 0s - loss: 0.6895 - accuracy: 0.5111 - val_loss: 0.6939 - val_accuracy: 0.4000
# Epoch 22/100
# 3/3 - 0s - loss: 0.6898 - accuracy: 0.5556 - val_loss: 0.6902 - val_accuracy: 0.6000
# Epoch 23/100
# 3/3 - 0s - loss: 0.6886 - accuracy: 0.7667 - val_loss: 0.6899 - val_accuracy: 0.6000
# Epoch 24/100
# 3/3 - 0s - loss: 0.6878 - accuracy: 0.6111 - val_loss: 0.6914 - val_accuracy: 0.4000
# Epoch 25/100
# 3/3 - 0s - loss: 0.6892 - accuracy: 0.5111 - val_loss: 0.6956 - val_accuracy: 0.4000
# Epoch 26/100
# 3/3 - 0s - loss: 0.6875 - accuracy: 0.5111 - val_loss: 0.6945 - val_accuracy: 0.4000
# Epoch 27/100
# 3/3 - 0s - loss: 0.6862 - accuracy: 0.5111 - val_loss: 0.6933 - val_accuracy: 0.4000
# Epoch 28/100
# 3/3 - 0s - loss: 0.6870 - accuracy: 0.5444 - val_loss: 0.6871 - val_accuracy: 0.8000
# Epoch 29/100
# 3/3 - 0s - loss: 0.6843 - accuracy: 0.8111 - val_loss: 0.6862 - val_accuracy: 0.8000
# Epoch 30/100
# 3/3 - 0s - loss: 0.6837 - accuracy: 0.8000 - val_loss: 0.6856 - val_accuracy: 0.8000
# Epoch 31/100
# 3/3 - 0s - loss: 0.6823 - accuracy: 0.7778 - val_loss: 0.6866 - val_accuracy: 0.5000
# Epoch 32/100
# 3/3 - 0s - loss: 0.6818 - accuracy: 0.5778 - val_loss: 0.6890 - val_accuracy: 0.4000
# Epoch 33/100
# 3/3 - 0s - loss: 0.6801 - accuracy: 0.5222 - val_loss: 0.6878 - val_accuracy: 0.5000
# Epoch 34/100
# 3/3 - 0s - loss: 0.6791 - accuracy: 0.5222 - val_loss: 0.6874 - val_accuracy: 0.5000
# Epoch 35/100
# 3/3 - 0s - loss: 0.6777 - accuracy: 0.5222 - val_loss: 0.6869 - val_accuracy: 0.5000
# Epoch 36/100
# 3/3 - 0s - loss: 0.6772 - accuracy: 0.5778 - val_loss: 0.6818 - val_accuracy: 0.7000
# Epoch 37/100
# 3/3 - 0s - loss: 0.6748 - accuracy: 0.7000 - val_loss: 0.6803 - val_accuracy: 0.7000
# Epoch 38/100
# 3/3 - 0s - loss: 0.6732 - accuracy: 0.7333 - val_loss: 0.6793 - val_accuracy: 0.7000
# Epoch 39/100
# 3/3 - 0s - loss: 0.6715 - accuracy: 0.7111 - val_loss: 0.6780 - val_accuracy: 0.7000
# Epoch 40/100
# 3/3 - 0s - loss: 0.6696 - accuracy: 0.7222 - val_loss: 0.6770 - val_accuracy: 0.7000
# Epoch 41/100
# 3/3 - 0s - loss: 0.6674 - accuracy: 0.7222 - val_loss: 0.6739 - val_accuracy: 0.8000
# Epoch 42/100
# 3/3 - 0s - loss: 0.6653 - accuracy: 0.7667 - val_loss: 0.6739 - val_accuracy: 0.7000
# Epoch 43/100
# 3/3 - 0s - loss: 0.6649 - accuracy: 0.6556 - val_loss: 0.6749 - val_accuracy: 0.6000
# Epoch 44/100
# 3/3 - 0s - loss: 0.6605 - accuracy: 0.7222 - val_loss: 0.6681 - val_accuracy: 0.8000
# Epoch 45/100
# 3/3 - 0s - loss: 0.6595 - accuracy: 0.8667 - val_loss: 0.6612 - val_accuracy: 0.9000
# Epoch 46/100
# 3/3 - 0s - loss: 0.6578 - accuracy: 0.9000 - val_loss: 0.6572 - val_accuracy: 0.9000
# Epoch 47/100
# 3/3 - 0s - loss: 0.6554 - accuracy: 0.8667 - val_loss: 0.6625 - val_accuracy: 0.8000
# Epoch 48/100
# 3/3 - 0s - loss: 0.6506 - accuracy: 0.8000 - val_loss: 0.6641 - val_accuracy: 0.7000
# Epoch 49/100
# 3/3 - 0s - loss: 0.6472 - accuracy: 0.7222 - val_loss: 0.6608 - val_accuracy: 0.8000
# Epoch 50/100
# 3/3 - 0s - loss: 0.6443 - accuracy: 0.7667 - val_loss: 0.6571 - val_accuracy: 0.8000
# Epoch 51/100
# 3/3 - 0s - loss: 0.6405 - accuracy: 0.8444 - val_loss: 0.6513 - val_accuracy: 0.9000
# Epoch 52/100
# 3/3 - 0s - loss: 0.6377 - accuracy: 0.9667 - val_loss: 0.6427 - val_accuracy: 0.9000
# Epoch 53/100
# 3/3 - 0s - loss: 0.6354 - accuracy: 0.8889 - val_loss: 0.6375 - val_accuracy: 0.9000
# Epoch 54/100
# 3/3 - 0s - loss: 0.6305 - accuracy: 0.9111 - val_loss: 0.6386 - val_accuracy: 0.9000
# Epoch 55/100
# 3/3 - 0s - loss: 0.6280 - accuracy: 0.9333 - val_loss: 0.6448 - val_accuracy: 0.8000
# Epoch 56/100
# 3/3 - 0s - loss: 0.6228 - accuracy: 0.8444 - val_loss: 0.6400 - val_accuracy: 0.8000
# Epoch 57/100
# 3/3 - 0s - loss: 0.6183 - accuracy: 0.8556 - val_loss: 0.6378 - val_accuracy: 0.8000
# Epoch 58/100
# 3/3 - 0s - loss: 0.6155 - accuracy: 0.9111 - val_loss: 0.6286 - val_accuracy: 0.9000
# Epoch 59/100
# 3/3 - 0s - loss: 0.6091 - accuracy: 0.9667 - val_loss: 0.6247 - val_accuracy: 0.9000
# Epoch 60/100
# 3/3 - 0s - loss: 0.6047 - accuracy: 0.9333 - val_loss: 0.6245 - val_accuracy: 0.9000
# Epoch 61/100
# 3/3 - 0s - loss: 0.6007 - accuracy: 0.9000 - val_loss: 0.6202 - val_accuracy: 0.9000
# Epoch 62/100
# 3/3 - 0s - loss: 0.5957 - accuracy: 0.9333 - val_loss: 0.6115 - val_accuracy: 0.9000
# Epoch 63/100
# 3/3 - 0s - loss: 0.5907 - accuracy: 0.9778 - val_loss: 0.6034 - val_accuracy: 0.9000
# Epoch 64/100
# 3/3 - 0s - loss: 0.5879 - accuracy: 0.9222 - val_loss: 0.5982 - val_accuracy: 0.9000
# Epoch 65/100
# 3/3 - 0s - loss: 0.5808 - accuracy: 0.9444 - val_loss: 0.6054 - val_accuracy: 0.9000
# Epoch 66/100
# 3/3 - 0s - loss: 0.5757 - accuracy: 0.8889 - val_loss: 0.6066 - val_accuracy: 0.8000
# Epoch 67/100
# 3/3 - 0s - loss: 0.5686 - accuracy: 0.8667 - val_loss: 0.5954 - val_accuracy: 0.9000
# Epoch 68/100
# 3/3 - 0s - loss: 0.5614 - accuracy: 0.9667 - val_loss: 0.5826 - val_accuracy: 0.9000
# Epoch 69/100
# 3/3 - 0s - loss: 0.5572 - accuracy: 0.9667 - val_loss: 0.5738 - val_accuracy: 1.0000
# Epoch 70/100
# 3/3 - 0s - loss: 0.5513 - accuracy: 0.9667 - val_loss: 0.5708 - val_accuracy: 0.9000
# Epoch 71/100
# 3/3 - 0s - loss: 0.5451 - accuracy: 0.9556 - val_loss: 0.5663 - val_accuracy: 0.9000
# Epoch 72/100
# 3/3 - 0s - loss: 0.5364 - accuracy: 0.9667 - val_loss: 0.5683 - val_accuracy: 0.9000
# Epoch 73/100
# 3/3 - 0s - loss: 0.5310 - accuracy: 0.9667 - val_loss: 0.5691 - val_accuracy: 0.9000
# Epoch 74/100
# 3/3 - 0s - loss: 0.5253 - accuracy: 0.9333 - val_loss: 0.5596 - val_accuracy: 0.9000
# Epoch 75/100
# 3/3 - 0s - loss: 0.5178 - accuracy: 0.9667 - val_loss: 0.5488 - val_accuracy: 0.9000
# Epoch 76/100
# 3/3 - 0s - loss: 0.5137 - accuracy: 0.9556 - val_loss: 0.5382 - val_accuracy: 0.9000
# Epoch 77/100
# 3/3 - 0s - loss: 0.5039 - accuracy: 0.9778 - val_loss: 0.5369 - val_accuracy: 0.9000
# Epoch 78/100
# 3/3 - 0s - loss: 0.4986 - accuracy: 0.9556 - val_loss: 0.5402 - val_accuracy: 0.9000
# Epoch 79/100
# 3/3 - 0s - loss: 0.4905 - accuracy: 0.9556 - val_loss: 0.5298 - val_accuracy: 0.9000
# Epoch 80/100
# 3/3 - 0s - loss: 0.4811 - accuracy: 0.9667 - val_loss: 0.5144 - val_accuracy: 0.9000
# Epoch 81/100
# 3/3 - 0s - loss: 0.4845 - accuracy: 0.9333 - val_loss: 0.5045 - val_accuracy: 1.0000
# Epoch 82/100
# 3/3 - 0s - loss: 0.4695 - accuracy: 0.9556 - val_loss: 0.5075 - val_accuracy: 0.9000
# Epoch 83/100
# 3/3 - 0s - loss: 0.4675 - accuracy: 0.9333 - val_loss: 0.5184 - val_accuracy: 0.9000
# Epoch 84/100
# 3/3 - 0s - loss: 0.4570 - accuracy: 0.9444 - val_loss: 0.4961 - val_accuracy: 0.9000
# Epoch 85/100
# 3/3 - 0s - loss: 0.4445 - accuracy: 0.9667 - val_loss: 0.4833 - val_accuracy: 0.9000
# Epoch 86/100
# 3/3 - 0s - loss: 0.4379 - accuracy: 0.9889 - val_loss: 0.4775 - val_accuracy: 0.9000
# Epoch 87/100
# 3/3 - 0s - loss: 0.4304 - accuracy: 0.9889 - val_loss: 0.4728 - val_accuracy: 0.9000
# Epoch 88/100
# 3/3 - 0s - loss: 0.4217 - accuracy: 0.9778 - val_loss: 0.4706 - val_accuracy: 0.9000
# Epoch 89/100
# 3/3 - 0s - loss: 0.4140 - accuracy: 0.9667 - val_loss: 0.4728 - val_accuracy: 0.9000
# Epoch 90/100
# 3/3 - 0s - loss: 0.4093 - accuracy: 0.9667 - val_loss: 0.4611 - val_accuracy: 0.9000
# Epoch 91/100
# 3/3 - 0s - loss: 0.4001 - accuracy: 0.9667 - val_loss: 0.4481 - val_accuracy: 0.9000
# Epoch 92/100
# 3/3 - 0s - loss: 0.3948 - accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.9000
# Epoch 93/100
# 3/3 - 0s - loss: 0.3843 - accuracy: 0.9889 - val_loss: 0.4359 - val_accuracy: 0.9000
# Epoch 94/100
# 3/3 - 0s - loss: 0.3781 - accuracy: 0.9778 - val_loss: 0.4411 - val_accuracy: 0.9000
# Epoch 95/100
# 3/3 - 0s - loss: 0.3721 - accuracy: 0.9667 - val_loss: 0.4289 - val_accuracy: 0.9000
# Epoch 96/100
# 3/3 - 0s - loss: 0.3655 - accuracy: 0.9667 - val_loss: 0.4138 - val_accuracy: 1.0000
# Epoch 97/100
# 3/3 - 0s - loss: 0.3564 - accuracy: 0.9889 - val_loss: 0.4084 - val_accuracy: 0.9000
# Epoch 98/100
# 3/3 - 0s - loss: 0.3470 - accuracy: 1.0000 - val_loss: 0.4054 - val_accuracy: 0.9000
# Epoch 99/100
# 3/3 - 0s - loss: 0.3458 - accuracy: 0.9667 - val_loss: 0.4076 - val_accuracy: 0.9000
# Epoch 100/100
# 3/3 - 0s - loss: 0.3335 - accuracy: 0.9667 - val_loss: 0.3925 - val_accuracy: 0.9000

# %%
def type_classifier(text):
    input_sequence = type_tok.texts_to_sequences([text])
    input_padded = pad_sequences(input_sequence, maxlen=max_length, padding = 'post', truncating = 'post')
    
    if text == "": return
    
    prediction_list = type_model.predict(input_padded)
    prediction_location = np.argmax(prediction_list)
    
    type_list = ['propositional', 'speech act']

    return(type_list[prediction_location])

# %%
Pthreshold = 0.5
SAthreshold = 0.5

def vague_classifier(txt,Type):
    text = clean_text(txt)
    
    if(Type == 'propositional'):
        input_sequence = proptok.texts_to_sequences([text])
        input_padded = pad_sequences(input_sequence, maxlen=max_length, padding = 'post', truncating = 'post')
        if text == "": return

        predicted_probability = prop_model.predict(input_padded)[0][0]

        if(predicted_probability <= Pthreshold):
            prediction = "not vague"
        elif(predicted_probability > Pthreshold):
            prediction = "vague"
            
    elif(Type == 'speech act'):
        input_sequence = speechacttok.texts_to_sequences([text])
        input_padded = pad_sequences(input_sequence, maxlen=max_length, padding = 'post', truncating = 'post')
        
        input_padded = np.array(input_padded[0])
        
        if text == "": return

        predicted_probability = speechact_model.predict(input_padded)[0][0]

        if(predicted_probability <= SAthreshold):
            prediction = "not vague"
        elif(predicted_probability > SAthreshold):
            prediction = "vague"
    
    print("INPUT: " + text)
    print("Type: " + Type)
    print("prediction: " + prediction)
    print(str(predicted_probability) + " activation")

# %%
def Krieger(text): return vague_classifier(text,type_classifier(text))

# %%
Krieger("Could you open this for me?")
# Out:
# INPUT: could you open this for me
# Type: propositional
# prediction: not vague
# 0.15203702 activation

# %% [markdown]
# ### Tensorboard

# %%
# %load_ext tensorboard

# %%
# !rm -rf ./logs/

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

type_history = type_model.fit(type_train_padded, nl_type_train, epochs = 300, 
                              validation_data = (type_test_padded, nl_type_test), 
                              verbose = 2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/300
# WARNING:tensorflow:From /home/jason/.local/lib/python3.6/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0392s vs `on_train_batch_end` time: 0.2398s). Check your callbacks.
# 4/4 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.8500
# Epoch 2/300
# 4/4 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.8550
# Epoch 3/300
# 4/4 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4100 - val_accuracy: 0.8500
# Epoch 4/300
# 4/4 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4079 - val_accuracy: 0.8475
# Epoch 5/300
# 4/4 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4077 - val_accuracy: 0.8425
# Epoch 6/300
# 4/4 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4504 - val_accuracy: 0.8150
# Epoch 7/300
# 4/4 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.4211 - val_accuracy: 0.8250
# Epoch 8/300
# 4/4 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.8500
# Epoch 9/300
# 4/4 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4707 - val_accuracy: 0.8500
# Epoch 10/300
# 4/4 - 0s - loss: 0.0148 - accuracy: 0.9900 - val_loss: 0.4558 - val_accuracy: 0.8525
# Epoch 11/300
# 4/4 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4216 - val_accuracy: 0.8500
# Epoch 12/300
# 4/4 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4104 - val_accuracy: 0.8450
# Epoch 13/300
# 4/4 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.8450
# Epoch 14/300
# 4/4 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.8450
# Epoch 15/300
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.8475
# Epoch 16/300
# 4/4 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4241 - val_accuracy: 0.8500
# Epoch 17/300
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4268 - val_accuracy: 0.8500
# Epoch 18/300
# 4/4 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.8500
# Epoch 19/300
# 4/4 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4206 - val_accuracy: 0.8550
# Epoch 20/300
# 4/4 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4244 - val_accuracy: 0.8550
# Epoch 21/300
# 4/4 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4218 - val_accuracy: 0.8550
# Epoch 22/300
# 4/4 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4195 - val_accuracy: 0.8450
# Epoch 23/300
# 4/4 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.8450
# Epoch 24/300
# 4/4 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8475
# Epoch 25/300
# 4/4 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.8475
# Epoch 26/300
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4180 - val_accuracy: 0.8475
# Epoch 27/300
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4186 - val_accuracy: 0.8475
# Epoch 28/300
# 4/4 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4189 - val_accuracy: 0.8450
# Epoch 29/300
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4220 - val_accuracy: 0.8475
# Epoch 30/300
# 4/4 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4242 - val_accuracy: 0.8475
# Epoch 31/300
# 4/4 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4236 - val_accuracy: 0.8450
# Epoch 32/300
# 4/4 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4240 - val_accuracy: 0.8475
# Epoch 33/300
# 4/4 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4227 - val_accuracy: 0.8475
# Epoch 34/300
# 4/4 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4218 - val_accuracy: 0.8450
# Epoch 35/300
# 4/4 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.8425
# Epoch 36/300
# 4/4 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4211 - val_accuracy: 0.8475
# Epoch 37/300
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4412 - val_accuracy: 0.8275
# Epoch 38/300
# 4/4 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4352 - val_accuracy: 0.8225
# Epoch 39/300
# 4/4 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.4226 - val_accuracy: 0.8475
# Epoch 40/300
# 4/4 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4313 - val_accuracy: 0.8500
# Epoch 41/300
# 4/4 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.8500
# Epoch 42/300
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4416 - val_accuracy: 0.8525
# Epoch 43/300
# 4/4 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 0.8500
# Epoch 44/300
# 4/4 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.8475
# Epoch 45/300
# 4/4 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4285 - val_accuracy: 0.8450
# Epoch 46/300
# 4/4 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.8425
# Epoch 47/300
# 4/4 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.8425
# Epoch 48/300
# 4/4 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4304 - val_accuracy: 0.8450
# Epoch 49/300
# 4/4 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.8500
# Epoch 50/300
# 4/4 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.8500
# Epoch 51/300
# 4/4 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8500
# Epoch 52/300
# 4/4 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 0.8450
# Epoch 53/300
# 4/4 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0.8475
# Epoch 54/300
# 4/4 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4371 - val_accuracy: 0.8500
# Epoch 55/300
# 4/4 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.8475
# Epoch 56/300
# 4/4 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.8450
# Epoch 57/300
# 4/4 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8425
# Epoch 58/300
# 4/4 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8425
# Epoch 59/300
# 4/4 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.8425
# Epoch 60/300
# 4/4 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8425
# Epoch 61/300
# 4/4 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4356 - val_accuracy: 0.8425
# Epoch 62/300
# 4/4 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4364 - val_accuracy: 0.8425
# Epoch 63/300
# 4/4 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.8425
# Epoch 64/300
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4386 - val_accuracy: 0.8450
# Epoch 65/300
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4390 - val_accuracy: 0.8450
# Epoch 66/300
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4395 - val_accuracy: 0.8450
# Epoch 67/300
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4429 - val_accuracy: 0.8475
# Epoch 68/300
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 0.8450
# Epoch 69/300
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.8425
# Epoch 70/300
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.8425
# Epoch 71/300
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.8425
# Epoch 72/300
# 4/4 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.8425
# Epoch 73/300
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.8425
# Epoch 74/300
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.8425
# Epoch 75/300
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8425
# Epoch 76/300
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.8425
# Epoch 77/300
# 4/4 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.8425
# Epoch 78/300
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.8425
# Epoch 79/300
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4412 - val_accuracy: 0.8425
# Epoch 80/300
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.8425
# Epoch 81/300
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 0.8425
# Epoch 82/300
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4401 - val_accuracy: 0.8425
# Epoch 83/300
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4408 - val_accuracy: 0.8425
# Epoch 84/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 85/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.8425
# Epoch 86/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4445 - val_accuracy: 0.8425
# Epoch 87/300
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.8425
# Epoch 88/300
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4456 - val_accuracy: 0.8425
# Epoch 89/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.8475
# Epoch 90/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4519 - val_accuracy: 0.8425
# Epoch 91/300
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.8425
# Epoch 92/300
# 4/4 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8225
# Epoch 93/300
# 4/4 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.8200
# Epoch 94/300
# 4/4 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4449 - val_accuracy: 0.8425
# Epoch 95/300
# 4/4 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.8500
# Epoch 96/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.8500
# Epoch 97/300
# 4/4 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.8500
# Epoch 98/300
# 4/4 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.8500
# Epoch 99/300
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.8425
# Epoch 100/300
# 4/4 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4477 - val_accuracy: 0.8425
# Epoch 101/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.8425
# Epoch 102/300
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8475
# Epoch 103/300
# 4/4 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.8425
# Epoch 104/300
# 4/4 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4625 - val_accuracy: 0.8400
# Epoch 105/300
# 4/4 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8475
# Epoch 106/300
# 4/4 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.8450
# Epoch 107/300
# 4/4 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8425
# Epoch 108/300
# 4/4 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8425
# Epoch 109/300
# 4/4 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4527 - val_accuracy: 0.8425
# Epoch 110/300
# 4/4 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.8425
# Epoch 111/300
# 4/4 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4533 - val_accuracy: 0.8425
# Epoch 112/300
# 4/4 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4562 - val_accuracy: 0.8425
# Epoch 113/300
# 4/4 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4564 - val_accuracy: 0.8425
# Epoch 114/300
# 4/4 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.8425
# Epoch 115/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8425
# Epoch 116/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.8425
# Epoch 117/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4545 - val_accuracy: 0.8425
# Epoch 118/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4545 - val_accuracy: 0.8425
# Epoch 119/300
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.8425
# Epoch 120/300
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.8450
# Epoch 121/300
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8400
# Epoch 122/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8400
# Epoch 123/300
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.8425
# Epoch 124/300
# 4/4 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.8425
# Epoch 125/300
# 4/4 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 0.8425
# Epoch 126/300
# 4/4 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4580 - val_accuracy: 0.8425
# Epoch 127/300
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.8425
# Epoch 128/300
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.8425
# Epoch 129/300
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.8425
# Epoch 130/300
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.8425
# Epoch 131/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4637 - val_accuracy: 0.8425
# Epoch 132/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.8450
# Epoch 133/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4633 - val_accuracy: 0.8425
# Epoch 134/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4650 - val_accuracy: 0.8450
# Epoch 135/300
# 4/4 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4682 - val_accuracy: 0.8400
# Epoch 136/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4684 - val_accuracy: 0.8400
# Epoch 137/300
# 4/4 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4668 - val_accuracy: 0.8450
# Epoch 138/300
# 4/4 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8425
# Epoch 139/300
# 4/4 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4633 - val_accuracy: 0.8425
# Epoch 140/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4636 - val_accuracy: 0.8425
# Epoch 141/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.8425
# Epoch 142/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8425
# Epoch 143/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8425
# Epoch 144/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.8425
# Epoch 145/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8425
# Epoch 146/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8425
# Epoch 147/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4723 - val_accuracy: 0.8400
# Epoch 148/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4740 - val_accuracy: 0.8400
# Epoch 149/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8375
# Epoch 150/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4676 - val_accuracy: 0.8425
# Epoch 151/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8425
# Epoch 152/300
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4697 - val_accuracy: 0.8425
# Epoch 153/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4760 - val_accuracy: 0.8375
# Epoch 154/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.8375
# Epoch 155/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8400
# Epoch 156/300
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4730 - val_accuracy: 0.8450
# Epoch 157/300
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.8425
# Epoch 158/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4701 - val_accuracy: 0.8425
# Epoch 159/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.8425
# Epoch 160/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4748 - val_accuracy: 0.8450
# Epoch 161/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4745 - val_accuracy: 0.8450
# Epoch 162/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.8425
# Epoch 163/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.8425
# Epoch 164/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4716 - val_accuracy: 0.8425
# Epoch 165/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4716 - val_accuracy: 0.8425
# Epoch 166/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.8425
# Epoch 167/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4747 - val_accuracy: 0.8425
# Epoch 168/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.8400
# Epoch 169/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.8375
# Epoch 170/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4815 - val_accuracy: 0.8375
# Epoch 171/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8425
# Epoch 172/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.8425
# Epoch 173/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4717 - val_accuracy: 0.8475
# Epoch 174/300
# 4/4 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.8525
# Epoch 175/300
# 4/4 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4748 - val_accuracy: 0.8425
# Epoch 176/300
# 4/4 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.8425
# Epoch 177/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.8375
# Epoch 178/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8400
# Epoch 179/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.8375
# Epoch 180/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.8375
# Epoch 181/300
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4772 - val_accuracy: 0.8425
# Epoch 182/300
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4830 - val_accuracy: 0.8250
# Epoch 183/300
# 4/4 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8200
# Epoch 184/300
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.8450
# Epoch 185/300
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.8425
# Epoch 186/300
# 4/4 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.8400
# Epoch 187/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.8425
# Epoch 188/300
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8375
# Epoch 189/300
# 4/4 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4975 - val_accuracy: 0.8200
# Epoch 190/300
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.8075
# Epoch 191/300
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4810 - val_accuracy: 0.8450
# Epoch 192/300
# 4/4 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.8400
# Epoch 193/300
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.8475
# Epoch 194/300
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5347 - val_accuracy: 0.8475
# Epoch 195/300
# 4/4 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5133 - val_accuracy: 0.8425
# Epoch 196/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8375
# Epoch 197/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.8425
# Epoch 198/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4844 - val_accuracy: 0.8425
# Epoch 199/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8425
# Epoch 200/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4846 - val_accuracy: 0.8425
# Epoch 201/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.8425
# Epoch 202/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8425
# Epoch 203/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8425
# Epoch 204/300
# 4/4 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.8475
# Epoch 205/300
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8525
# Epoch 206/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4879 - val_accuracy: 0.8425
# Epoch 207/300
# 4/4 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8425
# Epoch 208/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8425
# Epoch 209/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8375
# Epoch 210/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.8375
# Epoch 211/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.8425
# Epoch 212/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4916 - val_accuracy: 0.8450
# Epoch 213/300
# 4/4 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.8175
# Epoch 214/300
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4944 - val_accuracy: 0.8525
# Epoch 215/300
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4890 - val_accuracy: 0.8500
# Epoch 216/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4933 - val_accuracy: 0.8425
# Epoch 217/300
# 4/4 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.8375
# Epoch 218/300
# 4/4 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.8400
# Epoch 219/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8400
# Epoch 220/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.8375
# Epoch 221/300
# 4/4 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5005 - val_accuracy: 0.8375
# Epoch 222/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4962 - val_accuracy: 0.8425
# Epoch 223/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4954 - val_accuracy: 0.8425
# Epoch 224/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4985 - val_accuracy: 0.8450
# Epoch 225/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.8375
# Epoch 226/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8375
# Epoch 227/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8375
# Epoch 228/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.8375
# Epoch 229/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4994 - val_accuracy: 0.8425
# Epoch 230/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4990 - val_accuracy: 0.8425
# Epoch 231/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.8425
# Epoch 232/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4990 - val_accuracy: 0.8425
# Epoch 233/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.8425
# Epoch 234/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4992 - val_accuracy: 0.8425
# Epoch 235/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.8425
# Epoch 236/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5060 - val_accuracy: 0.8350
# Epoch 237/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.8425
# Epoch 238/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4972 - val_accuracy: 0.8450
# Epoch 239/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.8500
# Epoch 240/300
# 4/4 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4969 - val_accuracy: 0.8500
# Epoch 241/300
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.8425
# Epoch 242/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8450
# Epoch 243/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8375
# Epoch 244/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.8375
# Epoch 245/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.8375
# Epoch 246/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5069 - val_accuracy: 0.8400
# Epoch 247/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8425
# Epoch 248/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.8425
# Epoch 249/300
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5004 - val_accuracy: 0.8425
# Epoch 250/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.8425
# Epoch 251/300
# 4/4 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5045 - val_accuracy: 0.8500
# Epoch 252/300
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.8475
# Epoch 253/300
# 4/4 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.8425
# Epoch 254/300
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.8400
# Epoch 255/300
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8400
# Epoch 256/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.8400
# Epoch 257/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8400
# Epoch 258/300
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8375
# Epoch 259/300
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.8375
# Epoch 260/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.8425
# Epoch 261/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.8425
# Epoch 262/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8425
# Epoch 263/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8425
# Epoch 264/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.8425
# Epoch 265/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.8450
# Epoch 266/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8450
# Epoch 267/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8425
# Epoch 268/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5111 - val_accuracy: 0.8425
# Epoch 269/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.8450
# Epoch 270/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.8425
# Epoch 271/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8425
# Epoch 272/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8425
# Epoch 273/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.8425
# Epoch 274/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.8425
# Epoch 275/300
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.8425
# Epoch 276/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5149 - val_accuracy: 0.8400
# Epoch 277/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.8400
# Epoch 278/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8400
# Epoch 279/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.8375
# Epoch 280/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8375
# Epoch 281/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.8350
# Epoch 282/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.8375
# Epoch 283/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8425
# Epoch 284/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.8425
# Epoch 285/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8425
# Epoch 286/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8450
# Epoch 287/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8400
# Epoch 288/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5185 - val_accuracy: 0.8400
# Epoch 289/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.8350
# Epoch 290/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5201 - val_accuracy: 0.8375
# Epoch 291/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8425
# Epoch 292/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.8500
# Epoch 293/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.8450
# Epoch 294/300
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.8500
# Epoch 295/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5137 - val_accuracy: 0.8425
# Epoch 296/300
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5133 - val_accuracy: 0.8450
# Epoch 297/300
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8425
# Epoch 298/300
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8425
# Epoch 299/300
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.8425
# Epoch 300/300
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5187 - val_accuracy: 0.8425

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6008 (pid 13723), started 1 day, 2:39:29 ago. (Use '!kill 13723' to kill it.)
#       <iframe id="tensorboard-frame-2388770a71c1986a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2388770a71c1986a");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Exports

# %%
Pweights = prop_model.get_layer('Pembed').get_weights()[0]
SAweights = speechact_model.get_layer('SAembed').get_weights()[0]

# %%
prop_vocab = prop_word_index
Pout_v = io.open('Pvecs.tsv', 'w', encoding='utf-8')
Pout_m = io.open('Pmeta.tsv', 'w', encoding='utf-8')

for num, word in enumerate(prop_vocab):
    if num == 0: continue
    vec = Pweights[num]
    Pout_m.write(word + "\n")
    Pout_v.write('\t'.join([str(x) for x in vec]) + "\n")
Pout_v.close()
Pout_m.close()

try:
    from google.colab import files
except ImportError:
    pass
else:
    files.download('Pvecs.tsv')
    files.download('Pmeta.tsv')
    
##################################

speechact_vocab = speechact_word_index
SAout_v = io.open('SAvecs.tsv', 'w', encoding='utf-8')
SAout_m = io.open('SAmeta.tsv', 'w', encoding='utf-8')

for num, word in enumerate(speechact_vocab):
    if num == 0: continue
    vec = SAweights[num]
    SAout_m.write(word + "\n")
    SAout_v.write('\t'.join([str(x) for x in vec]) + "\n")
SAout_v.close()
SAout_m.close()

try:
    from google.colab import files
except ImportError:
    pass
else:
    files.download('SAvecs.tsv')
    files.download('SAmeta.tsv')

# %%
def update1(df, word, column):
    loc = df.loc[df['Words']==word]
    locI = int(loc.index.tolist()[0])
    new_value = int(loc[column]) + 1
    new_v_series = pd.Series([new_value], name=column, index=[locI])
    df.update(new_v_series)
    return df

def binDecode(x, thres):
    if (x < thres):
        return 0
    else:
        return 1

def Count_Correct(model, test_data, test_padded, test_label, word_index, thres):
    predicted_labels = model.predict(test_padded)
    words = list(word_index.keys())
    
    df = pd.DataFrame(columns = ['Words', 'Correct', 'Total', 'Rightly Vague'])
    df['Words'] = words
    df['Correct'] = [0]*len(word_index)
    df['Total'] = [0]*len(word_index)
    df['Rightly Vague'] = [0]*len(word_index)
    df['Incorrectly Vague'] = [0]*len(word_index)
    
    for i in range(len(test_data)):
        boo = (binDecode(float(predicted_labels[i]), thres) == binDecode(float(test_label[i]), thres))
        element = test_data[i]
        for word in element.split():
            if (word in (df.Words.values)):
                word = word
            else: word = "<OOV>"
            df = update1(df, word, 'Total')
            if boo:
                df = update1(df, word, 'Correct')
                if (binDecode(predicted_labels[i], thres) == 1):
                    df = update1(df, word, 'Rightly Vague') 
            else:
                if (binDecode(predicted_labels[i], thres) == 1):
                    df = update1(df, word, 'Incorrectly Vague')
    return(df)

# %%
Propdf = Count_Correct(prop_model, prop_test, prop_test_padded, prop_label_test, prop_word_index, Pthreshold)

# %%
SpeechActdf = Count_Correct(speechact_model, speechact_test, speechact_test_padded, speechact_label_test, speechact_word_index, SAthreshold)

# %%
SpeechActdf
# Out:
#       Words  Correct  Total  Rightly Vague  Incorrectly Vague
# 0         i      8.0    8.0            7.0                  0
# 1       the      1.0    2.0            0.0                  0
# 2        to      2.0    2.0            1.0                  0
# 3      that      2.0    2.0            2.0                  0
# 4       you      2.0    3.0            2.0                  0
# ..      ...      ...    ...            ...                ...
# 185   wants      0.0    0.0            0.0                  0
# 186  orange      0.0    0.0            0.0                  0
# 187    pass      0.0    0.0            0.0                  0
# 188    salt      0.0    0.0            0.0                  0
# 189   <OOV>     13.0   14.0            9.0                  0
#
# [190 rows x 5 columns]

# %% [markdown]
# ## Export

# %%
chdir(cwd)
if (os.path.exists(cwd+"/ModelsVL")):
    print("File exists")
else:
    makedirs("ModelsVL")
    chdir(cwd + "/ModelsVL")

    type_model.save('type_model.h5')
    prop_model.save('prop_model.h5')
    speechact_model.save('speechact_model.h5')

    with open('type_tok.pickle', 'wb') as handle:
        pickle.dump(type_tok, handle, protocol=pickle.HIGHEST_PROTOCOL)
    with open('proptok.pickle', 'wb') as handle:
        pickle.dump(proptok, handle, protocol=pickle.HIGHEST_PROTOCOL)
    with open('speechacttok.pickle', 'wb') as handle:
        pickle.dump(speechacttok, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# File exists

# %%
chdir(cwd)
if (os.path.exists(cwd+"/VLdf")):
    print("File exists")
else:
    makedirs("VLdf")
    chdir(cwd + "/VLdf")
    
    Propdf.to_csv("Propdf.csv")
    SpeechActdf.to_csv("SpeechActdf.csv")
# Out:
# File exists
