# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix
import seaborn as sns

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

import os
from os import makedirs
from os import chdir
from os import path
cwd = os.getcwd()
# Out:
# [nltk_data] Downloading package stopwords to /home/jason/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
StopWords = (stopwords.words('english'))

# %%
Propdf = pd.read_csv(cwd + '/VLdf/Propdf.csv')
SpeechActdf = pd.read_csv(cwd + '/VLdf/SpeechActdf.csv')


Propdf['FalseVague%'] = Propdf['Incorrectly Vague']/Propdf['Total']
Propdf['TrueVague%'] = Propdf['Rightly Vague']/Propdf['Total']
Propdf['success'] = Propdf['Correct']/Propdf['Total']

SpeechActdf['FalseVague%'] = SpeechActdf['Incorrectly Vague']/SpeechActdf['Total']
SpeechActdf['TrueVague%'] = SpeechActdf['Rightly Vague']/SpeechActdf['Total']
SpeechActdf['success'] = SpeechActdf['Correct']/SpeechActdf['Total']

# %%
def reduceDF(df, total, topn, topcat):
    df = df[df['Total'] > total]
    df = df[~df.Words.isin(StopWords)]
    
    return df.nlargest(topn, topcat)
    #return df.nsmallest(topn, topcat)

# %%
Propfinaldf = reduceDF(Propdf, 2, 15, 'TrueVague%')

# %%
SpeechActfinaldf = reduceDF(SpeechActdf, 0, 15, 'TrueVague%')

# %%
SpeechActfinaldf
# Out:
#      Unnamed: 0    Words  Correct  Total  Rightly Vague  Incorrectly Vague  \
# 7             7       go      1.0    1.0            0.0                  0
# 25           25      say      2.0    2.0            2.0                  0
# 28           28      get      1.0    1.0            1.0                  0
# 32           32     need      1.0    1.0            1.0                  0
# 36           36     tell      1.0    1.0            1.0                  0
# 39           39    sorry      1.0    1.0            1.0                  0
# 45           45  tonight      1.0    1.0            0.0                  0
# 47           47    going      1.0    1.0            0.0                  0
# 59           59   cannot      1.0    2.0            1.0                  0
# 95           95      got      1.0    1.0            1.0                  0
# 130         130      tea      1.0    1.0            0.0                  0
# ...

# %%
chdir(cwd)

chdir(cwd + "/VLdf")
    
Propfinaldf.to_csv("Propfinaldf.csv")
SpeechActfinaldf.to_csv("SpeechActfinaldf.csv")
